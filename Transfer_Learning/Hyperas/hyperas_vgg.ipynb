# %%
# !pip install --upgrade pactools
# !pip install hyperas
# !pip install hyperopt
# !pip install -U -q PyDrive
# Out:
# Requirement already up-to-date: pactools in /usr/local/lib/python3.6/dist-packages (0.3)
# Requirement already satisfied: hyperas in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.3)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from hyperas) (2.4.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.6.1)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.1.2)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from hyperas) (1.0.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.0.7)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (1.18.5)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (4.6.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (1.4.2)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.11.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.6.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.4.4)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.1.3)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (4.3.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (3.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (1.15.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (2.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (0.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (4.41.1)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.7.5)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.2.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (7.5.1)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.10.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.3.1)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (2.6.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.4->nbconvert->hyperas) (1.1.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.2->nbconvert->hyperas) (4.4.2)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->hyperas) (0.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->hyperas) (20.4)
# Requirement already satisfied: jupyter-client>=4.1 in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->hyperas) (5.3.5)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->hyperas) (1.9.0)
# Requirement already satisfied: pyzmq>=17.1 in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->hyperas) (19.0.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (1.0.18)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (5.5.0)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->hyperas) (3.5.1)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->jupyter->hyperas) (5.1.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (0.8.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->hyperas) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client>=4.1->qtconsole->jupyter->hyperas) (2.8.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->hyperas) (0.2.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (49.2.0)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.7.5)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (4.8.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook->jupyter->hyperas) (0.6.0)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)

# %%
# Install the PyDrive wrapper & import libraries.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title='hyperas_vgg.ipynb'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('hyperas_vgg.ipynb')

# %%
from hyperopt import Trials, STATUS_OK, tpe
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MaxNLocator

#TESNORFOW
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models

#KERAS LIBRARIES
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout , Flatten,BatchNormalization,Conv2D,MaxPooling2D, Activation,LSTM,Embedding,Input,GlobalAveragePooling2D
from keras.regularizers import l1, l2, l1_l2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend 
from keras.utils import np_utils
from keras.utils import to_categorical

#CROSS VALIDATION
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from pactools.grid_search import GridSearchCVProgressBar

#WRAPPERS NEEDED FOR GRIDSEARCH
from keras.wrappers.scikit_learn import KerasClassifier
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split

from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
def data():
  train1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train.npy',allow_pickle=True)
  train_labels1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train_labels.npy',allow_pickle=True)
  train2,test1, train_labels2,test_labels1 = train_test_split(train1, train_labels1, test_size=0.2,random_state=42)
  x_train=train2/225.0
  y_train = pd.get_dummies(train_labels2)

  x_test=test1/225.0
  y_test = pd.get_dummies(test_labels1)
  return x_train,y_train,x_test,y_test

# %%
IMG_SHAPE1=(64,64,3) # θα το προσαρμόσουμε

vgg19 = keras.applications.vgg19.VGG19(input_shape=IMG_SHAPE1,
                                               include_top=False,
                                               weights='imagenet')

# %%
def create_model_dense_vgg(x_train,y_train,x_test,y_test): 
  IMG_SHAPE1=(64,64,3) # θα το προσαρμόσουμε

  vgg19 = keras.applications.vgg19.VGG19(input_shape=IMG_SHAPE1,
                                               include_top=False,
                                               weights='imagenet')
  tempvg=vgg19
  froz={{choice([1,3,5,8,10,12,15,17])}}
  for layer in tempvg.layers[:(-1)*froz]:
    layer.trainable = False
  
  model = tf.keras.Sequential()
  model.add(tempvg)
  if ({{choice([0,1])}}):
    model.add(keras.layers.Flatten())
  else:
    model.add(keras.layers.GlobalAveragePooling2D())
  dense_layer_size={{choice([0,1,2,3])}}
  if (dense_layer_size==3):
    model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  elif (dense_layer_size==2):
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  elif (dense_layer_size==1):
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  else:
    layers=[]
    for i in range(len(layers)):
          model.add(keras.layers.Dense(layers[i], activation='relu'))
          model.add(keras.layers.Dropout(0.1))
  model.add(keras.layers.Dense(3,activation="softmax"))
  print('froz=',froz,'dense_layers=',dense_layer_size)
  model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy"])
  result = model.fit(x_train, y_train,
              batch_size=1000,
              epochs=30,
              verbose=2,
              validation_data=(x_test, y_test))
  validation_acc = np.amax(result.history['val_accuracy']) 
  print('Best validation acc of epoch:', validation_acc)
  return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
best_run, best_model = optim.minimize(model=create_model_dense_vgg,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=300,
                                          notebook_name='hyperas_vgg',
                                          trials=Trials())
X_train, Y_train, X_test, Y_test = data()
print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))
print("Best performing model chosen hyper-parameters:")
print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     from pydrive.auth import GoogleAuth
# except:
#     pass
#
# try:
#     from pydrive.drive import GoogleDrive
# except:
#     pass
#
# try:
#     from google.colab import auth
# except:
#     pass
#
# try:
#     from oauth2client.client import GoogleCredentials
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from matplotlib.ticker import MaxNLocator
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow import keras
# except:
#     pass
#
# try:
#     from keras import datasets, layers, models
# except:
#     pass
#
# try:
#     from keras.preprocessing.text import Tokenizer
# except:
#     pass
#
# try:
#     from keras.models import Sequential, Model
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Conv2D, MaxPooling2D, Activation, LSTM, Embedding, Input, GlobalAveragePooling2D
# except:
#     pass
#
# try:
#     from keras.regularizers import l1, l2, l1_l2
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from keras import backend
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras.utils import to_categorical
# except:
#     pass
#
# try:
#     from sklearn.model_selection import StratifiedKFold
# except:
#     pass
#
# try:
#     from sklearn.model_selection import GridSearchCV
# except:
#     pass
#
# try:
#     from pactools.grid_search import GridSearchCVProgressBar
# except:
#     pass
#
# try:
#     from keras.wrappers.scikit_learn import KerasClassifier
# except:
#     pass
#
# try:
#     from keras.wrappers.scikit_learn import KerasRegressor
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'froz': hp.choice('froz', [1,3,5,8,10,12,15,17]),
#         'if': hp.choice('if', [0,1]),
#         'dense_layer_size': hp.choice('dense_layer_size', [0,1,2,3]),
#         'Dropout': hp.choice('Dropout', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_1': hp.choice('Dropout_1', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_2': hp.choice('Dropout_2', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_3': hp.choice('Dropout_3', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_4': hp.choice('Dropout_4', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#     }
#
# >>> Data
#   1:
#   2: train1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train.npy',allow_pickle=True)
#   3: train_labels1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train_labels.npy',allow_pickle=True)
#   4: train2,test1, train_labels2,test_labels1 = train_test_split(train1, train_labels1, test_size=0.2,random_state=42)
#   5: x_train=train2/225.0
#   6: y_train = pd.get_dummies(train_labels2)
#   7:
#   8: x_test=test1/225.0
#   9: y_test = pd.get_dummies(test_labels1)
#  10:
#  11:
#  12:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:   IMG_SHAPE1=(64,64,3) # θα το προσαρμόσουμε
#    4:
#    5:   vgg19 = keras.applications.vgg19.VGG19(input_shape=IMG_SHAPE1,
#    6:                                                include_top=False,
#    7:                                                weights='imagenet')
#    8:   tempvg=vgg19
#    9:   froz=space['froz']
#   10:   for layer in tempvg.layers[:(-1)*froz]:
#   11:     layer.trainable = False
#   12:
#   13:   model = tf.keras.Sequential()
#   14:   model.add(tempvg)
#   15:   if (space['if']):
#   16:     model.add(keras.layers.Flatten())
#   17:   else:
#   18:     model.add(keras.layers.GlobalAveragePooling2D())
#   19:   dense_layer_size=space['dense_layer_size']
#   20:   if (dense_layer_size==3):
#   21:     model.add(keras.layers.Dense(128, activation='relu'))
#   22:     model.add(keras.layers.Dropout(0.5))
#   23:     model.add(keras.layers.Dense(64, activation='relu'))
#   24:     model.add(keras.layers.Dropout(space['Dropout']))
#   25:     model.add(keras.layers.Dense(32, activation='relu'))
#   26:     model.add(keras.layers.Dropout(space['Dropout_1']))
#   27:   elif (dense_layer_size==2):
#   28:     model.add(keras.layers.Dense(64, activation='relu'))
#   29:     model.add(keras.layers.Dropout(space['Dropout_2']))
#   30:     model.add(keras.layers.Dense(32, activation='relu'))
#   31:     model.add(keras.layers.Dropout(space['Dropout_3']))
#   32:   elif (dense_layer_size==1):
#   33:     model.add(keras.layers.Dense(32, activation='relu'))
#   34:     model.add(keras.layers.Dropout(space['Dropout_4']))
#   35:   else:
#   36:     layers=[]
#   37:     for i in range(len(layers)):
#   38:           model.add(keras.layers.Dense(layers[i], activation='relu'))
#   39:           model.add(keras.layers.Dropout(0.1))
#   40:   model.add(keras.layers.Dense(3,activation="softmax"))
#   41:   print('froz=',froz,'dense_layers=',dense_layer_size)
#   42:   model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy"])
#   43:   result = model.fit(x_train, y_train,
#   44:               batch_size=1000,
#   45:               epochs=30,
#   46:               verbose=2,
#   47:               validation_data=(x_test, y_test))
#   48:   validation_acc = np.amax(result.history['val_accuracy'])
#   49:   print('Best validation acc of epoch:', validation_acc)
#   50:   return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   51:
# froz=
# 3
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 5s - loss: 0.9313 - accuracy: 0.6157 - val_loss: 0.4868 - val_accuracy: 0.8055
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.4733 - accuracy: 0.8174 - val_loss: 0.4098 - val_accuracy: 0.8391
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.3893 - accuracy: 0.8511 - val_loss: 0.3558 - val_accuracy: 0.8633
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.3405 - accuracy: 0.8718 - val_loss: 0.3212 - val_accuracy: 0.8815
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.3118 - accuracy: 0.8819 - val_loss: 0.3054 - val_accuracy: 0.8847
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.2873 - accuracy: 0.8924 - val_loss: 0.3234 - val_accuracy: 0.8793
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.2828 - accuracy: 0.8922 - val_loss: 0.3698 - val_accuracy: 0.8591
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.2810 - accuracy: 0.8933 - val_loss: 0.3377 - val_accuracy: 0.8638
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.2529 - accuracy: 0.9049 - val_loss: 0.3202 - val_accuracy: 0.8704
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.2400 - accuracy: 0.9099 - val_loss: 0.2824 - val_accuracy: 0.8956
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.2275 - accuracy: 0.9149 - val_loss: 0.2721 - val_accuracy: 0.9000
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.2109 - accuracy: 0.9216 - val_loss: 0.3348 - val_accuracy: 0.8808
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.2132 - accuracy: 0.9194 - val_loss: 0.3606 - val_accuracy: 0.8682
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.2122 - accuracy: 0.9197 - val_loss: 0.2799 - val_accuracy: 0.8939
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.1932 - accuracy: 0.9271 - val_loss: 0.2792 - val_accuracy: 0.8993
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.2000 - accuracy: 0.9236 - val_loss: 0.2838 - val_accuracy: 0.8956
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.1707 - accuracy: 0.9365 - val_loss: 0.2674 - val_accuracy: 0.9047
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.1601 - accuracy: 0.9405 - val_loss: 0.2657 - val_accuracy: 0.9025
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.1527 - accuracy: 0.9446 - val_loss: 0.2778 - val_accuracy: 0.9000
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.1716 - accuracy: 0.9327 - val_loss: 0.3237 - val_accuracy: 0.8820
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.1635 - accuracy: 0.9398 - val_loss: 0.2636 - val_accuracy: 0.9060
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.1334 - accuracy: 0.9522 - val_loss: 0.2907 - val_accuracy: 0.8983
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.1410 - accuracy: 0.9485 - val_loss: 0.2725 - val_accuracy: 0.9038
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.1189 - accuracy: 0.9579 - val_loss: 0.2722 - val_accuracy: 0.9082
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.1105 - accuracy: 0.9617 - val_loss: 0.2964 - val_accuracy: 0.9047
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.1056 - accuracy: 0.9636 - val_loss: 0.2774 - val_accuracy: 0.9067
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.0951 - accuracy: 0.9671 - val_loss: 0.3085 - val_accuracy: 0.8973
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.1210 - accuracy: 0.9543 - val_loss: 0.3877 - val_accuracy: 0.8739
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.1096 - accuracy: 0.9615 - val_loss: 0.3398 - val_accuracy: 0.8924
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.0943 - accuracy: 0.9654 - val_loss: 0.2987 - val_accuracy: 0.9070
#
# Best validation acc of epoch:
# 0.9081934690475464
# froz=
# 15
# dense_layers=
# 1
# Epoch 1/30
# 17/17 - 8s - loss: 13.1172 - accuracy: 0.4043 - val_loss: 1.0429 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 7s - loss: 1.0480 - accuracy: 0.4585 - val_loss: 1.0323 - val_accuracy: 0.5121
#
# Epoch 3/30
# 17/17 - 7s - loss: 1.0314 - accuracy: 0.4969 - val_loss: 0.9805 - val_accuracy: 0.5185
#
# Epoch 4/30
# 17/17 - 7s - loss: 0.9972 - accuracy: 0.5358 - val_loss: 0.9397 - val_accuracy: 0.5713
#
# Epoch 5/30
# 17/17 - 7s - loss: 0.9647 - accuracy: 0.5621 - val_loss: 0.9545 - val_accuracy: 0.5380
#
# Epoch 6/30
# 17/17 - 7s - loss: 0.9227 - accuracy: 0.5863 - val_loss: 0.8521 - val_accuracy: 0.6214
#
# Epoch 7/30
# 17/17 - 7s - loss: 0.9162 - accuracy: 0.5829 - val_loss: 0.8755 - val_accuracy: 0.6251
#
# Epoch 8/30
# 17/17 - 7s - loss: 0.8609 - accuracy: 0.6132 - val_loss: 0.7834 - val_accuracy: 0.6520
#
# Epoch 9/30
# 17/17 - 7s - loss: 0.7863 - accuracy: 0.6370 - val_loss: 0.6871 - val_accuracy: 0.6839
#
# Epoch 10/30
# 17/17 - 7s - loss: 0.7405 - accuracy: 0.6678 - val_loss: 0.6463 - val_accuracy: 0.7189
#
# Epoch 11/30
# 17/17 - 7s - loss: 0.6581 - accuracy: 0.7334 - val_loss: 0.6417 - val_accuracy: 0.7078
#
# Epoch 12/30
# 17/17 - 7s - loss: 0.7120 - accuracy: 0.7253 - val_loss: 0.6834 - val_accuracy: 0.7268
#
# Epoch 13/30
# 17/17 - 7s - loss: 0.6384 - accuracy: 0.7576 - val_loss: 0.4702 - val_accuracy: 0.8292
#
# Epoch 14/30
# 17/17 - 7s - loss: 0.4988 - accuracy: 0.8237 - val_loss: 0.8428 - val_accuracy: 0.6525
#
# Epoch 15/30
# 17/17 - 7s - loss: 0.7188 - accuracy: 0.6861 - val_loss: 0.5667 - val_accuracy: 0.7905
#
# Epoch 16/30
# 17/17 - 7s - loss: 0.5266 - accuracy: 0.8070 - val_loss: 0.4210 - val_accuracy: 0.8480
#
# Epoch 17/30
# 17/17 - 7s - loss: 0.4440 - accuracy: 0.8484 - val_loss: 0.3924 - val_accuracy: 0.8519
#
# Epoch 18/30
# 17/17 - 7s - loss: 0.4061 - accuracy: 0.8601 - val_loss: 0.4255 - val_accuracy: 0.8448
#
# Epoch 19/30
# 17/17 - 7s - loss: 0.4969 - accuracy: 0.8195 - val_loss: 0.4457 - val_accuracy: 0.8359
#
# Epoch 20/30
# 17/17 - 7s - loss: 0.3907 - accuracy: 0.8622 - val_loss: 0.3734 - val_accuracy: 0.8576
#
# Epoch 21/30
# 17/17 - 7s - loss: 0.3954 - accuracy: 0.8624 - val_loss: 0.4290 - val_accuracy: 0.8364
#
# Epoch 22/30
# 17/17 - 7s - loss: 0.3858 - accuracy: 0.8678 - val_loss: 0.3762 - val_accuracy: 0.8620
#
# Epoch 23/30
# 17/17 - 7s - loss: 0.3604 - accuracy: 0.8764 - val_loss: 0.3441 - val_accuracy: 0.8796
#
# Epoch 24/30
# 17/17 - 7s - loss: 0.3220 - accuracy: 0.8918 - val_loss: 0.3224 - val_accuracy: 0.8882
#
# Epoch 25/30
# 17/17 - 7s - loss: 0.2932 - accuracy: 0.9018 - val_loss: 0.3040 - val_accuracy: 0.8956
#
# Epoch 26/30
# 17/17 - 7s - loss: 0.3104 - accuracy: 0.8947 - val_loss: 0.3457 - val_accuracy: 0.8776
#
# Epoch 27/30
# 17/17 - 7s - loss: 0.3052 - accuracy: 0.9003 - val_loss: 0.3073 - val_accuracy: 0.8951
#
# Epoch 28/30
# 17/17 - 7s - loss: 0.2732 - accuracy: 0.9107 - val_loss: 0.2821 - val_accuracy: 0.8983
#
# Epoch 29/30
# 17/17 - 7s - loss: 0.2607 - accuracy: 0.9152 - val_loss: 0.2705 - val_accuracy: 0.9013
#
# Epoch 30/30
# 17/17 - 7s - loss: 0.2610 - accuracy: 0.9131 - val_loss: 0.3501 - val_accuracy: 0.8835
#
# Best validation acc of epoch:
# 0.901283323764801
# froz=
# 5
# dense_layers=
# 2
# Epoch 1/30
# 17/17 - 4s - loss: 1.2267 - accuracy: 0.3799 - val_loss: 1.0731 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 4s - loss: 1.0700 - accuracy: 0.4255 - val_loss: 0.9417 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.8905 - accuracy: 0.4927 - val_loss: 0.8347 - val_accuracy: 0.6249
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.8216 - accuracy: 0.6434 - val_loss: 0.7228 - val_accuracy: 0.7290
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.6349 - accuracy: 0.7372 - val_loss: 0.5350 - val_accuracy: 0.7747
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.5153 - accuracy: 0.8165 - val_loss: 0.3508 - val_accuracy: 0.8786
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.3962 - accuracy: 0.8708 - val_loss: 0.3183 - val_accuracy: 0.8833
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.3437 - accuracy: 0.8871 - val_loss: 0.3432 - val_accuracy: 0.8687
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.3289 - accuracy: 0.8928 - val_loss: 0.2786 - val_accuracy: 0.8963
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.2811 - accuracy: 0.9063 - val_loss: 0.2583 - val_accuracy: 0.9055
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.2628 - accuracy: 0.9126 - val_loss: 0.3155 - val_accuracy: 0.8830
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.2690 - accuracy: 0.9079 - val_loss: 0.2458 - val_accuracy: 0.9079
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.2508 - accuracy: 0.9143 - val_loss: 0.2920 - val_accuracy: 0.8936
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.2474 - accuracy: 0.9175 - val_loss: 0.2464 - val_accuracy: 0.9062
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.2073 - accuracy: 0.9289 - val_loss: 0.2331 - val_accuracy: 0.9181
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.1875 - accuracy: 0.9374 - val_loss: 0.2602 - val_accuracy: 0.9072
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.1751 - accuracy: 0.9429 - val_loss: 0.2452 - val_accuracy: 0.9112
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.1538 - accuracy: 0.9481 - val_loss: 0.2742 - val_accuracy: 0.9097
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.1480 - accuracy: 0.9505 - val_loss: 0.3643 - val_accuracy: 0.8926
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.2259 - accuracy: 0.9234 - val_loss: 0.2545 - val_accuracy: 0.9075
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.1763 - accuracy: 0.9384 - val_loss: 0.4000 - val_accuracy: 0.8877
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.1784 - accuracy: 0.9403 - val_loss: 0.2548 - val_accuracy: 0.9171
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.1474 - accuracy: 0.9501 - val_loss: 0.2551 - val_accuracy: 0.9079
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.1283 - accuracy: 0.9593 - val_loss: 0.2917 - val_accuracy: 0.9149
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.0989 - accuracy: 0.9692 - val_loss: 0.3440 - val_accuracy: 0.9136
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.0972 - accuracy: 0.9692 - val_loss: 0.3212 - val_accuracy: 0.9144
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.0777 - accuracy: 0.9756 - val_loss: 0.3583 - val_accuracy: 0.9200
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.1052 - accuracy: 0.9667 - val_loss: 0.2734 - val_accuracy: 0.9178
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.0939 - accuracy: 0.9696 - val_loss: 0.3504 - val_accuracy: 0.9193
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.0801 - accuracy: 0.9743 - val_loss: 0.5001 - val_accuracy: 0.8924
#
# Best validation acc of epoch:
# 0.9200394749641418
# froz=
# 12
# dense_layers=
# 1
# Epoch 1/30
# 17/17 - 6s - loss: 3.4944 - accuracy: 0.4146 - val_loss: 1.0565 - val_accuracy: 0.4689
#
# Epoch 2/30
# 17/17 - 6s - loss: 1.0594 - accuracy: 0.4520 - val_loss: 1.0337 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 6s - loss: 1.0329 - accuracy: 0.4566 - val_loss: 0.9950 - val_accuracy: 0.4640
#
# Epoch 4/30
# 17/17 - 6s - loss: 0.9501 - accuracy: 0.5133 - val_loss: 0.9369 - val_accuracy: 0.5296
#
# Epoch 5/30
# 17/17 - 6s - loss: 0.8717 - accuracy: 0.5891 - val_loss: 0.7858 - val_accuracy: 0.6503
#
# Epoch 6/30
# 17/17 - 6s - loss: 0.8234 - accuracy: 0.6252 - val_loss: 0.7148 - val_accuracy: 0.6681
#
# Epoch 7/30
# 17/17 - 6s - loss: 0.7854 - accuracy: 0.6486 - val_loss: 0.6901 - val_accuracy: 0.7238
#
# Epoch 8/30
# 17/17 - 6s - loss: 0.6293 - accuracy: 0.7397 - val_loss: 0.5647 - val_accuracy: 0.7737
#
# Epoch 9/30
# 17/17 - 6s - loss: 0.5441 - accuracy: 0.7919 - val_loss: 0.5347 - val_accuracy: 0.7942
#
# Epoch 10/30
# 17/17 - 6s - loss: 0.5418 - accuracy: 0.7970 - val_loss: 0.4508 - val_accuracy: 0.8324
#
# Epoch 11/30
# 17/17 - 6s - loss: 0.4656 - accuracy: 0.8341 - val_loss: 0.4123 - val_accuracy: 0.8462
#
# Epoch 12/30
# 17/17 - 6s - loss: 0.4086 - accuracy: 0.8545 - val_loss: 0.3470 - val_accuracy: 0.8697
#
# Epoch 13/30
# 17/17 - 6s - loss: 0.3793 - accuracy: 0.8666 - val_loss: 0.3322 - val_accuracy: 0.8773
#
# Epoch 14/30
# 17/17 - 6s - loss: 0.3897 - accuracy: 0.8627 - val_loss: 0.3244 - val_accuracy: 0.8788
#
# Epoch 15/30
# 17/17 - 6s - loss: 0.3344 - accuracy: 0.8844 - val_loss: 0.3085 - val_accuracy: 0.8875
#
# Epoch 16/30
# 17/17 - 6s - loss: 0.3154 - accuracy: 0.8882 - val_loss: 0.3116 - val_accuracy: 0.8855
#
# Epoch 17/30
# 17/17 - 6s - loss: 0.3067 - accuracy: 0.8926 - val_loss: 0.4107 - val_accuracy: 0.8638
#
# Epoch 18/30
# 17/17 - 6s - loss: 0.3223 - accuracy: 0.8867 - val_loss: 0.2863 - val_accuracy: 0.8993
#
# Epoch 19/30
# 17/17 - 6s - loss: 0.2948 - accuracy: 0.8994 - val_loss: 0.3244 - val_accuracy: 0.8870
#
# Epoch 20/30
# 17/17 - 6s - loss: 0.2915 - accuracy: 0.9008 - val_loss: 0.2618 - val_accuracy: 0.9033
#
# Epoch 21/30
# 17/17 - 6s - loss: 0.2590 - accuracy: 0.9106 - val_loss: 0.3258 - val_accuracy: 0.8793
#
# Epoch 22/30
# 17/17 - 6s - loss: 0.2851 - accuracy: 0.8999 - val_loss: 0.2736 - val_accuracy: 0.8956
#
# Epoch 23/30
# 17/17 - 6s - loss: 0.2535 - accuracy: 0.9120 - val_loss: 0.2683 - val_accuracy: 0.8993
#
# Epoch 24/30
# 17/17 - 6s - loss: 0.2480 - accuracy: 0.9123 - val_loss: 0.2786 - val_accuracy: 0.8981
#
# Epoch 25/30
# 17/17 - 6s - loss: 0.2387 - accuracy: 0.9179 - val_loss: 0.2483 - val_accuracy: 0.9116
#
# Epoch 26/30
# 17/17 - 6s - loss: 0.2153 - accuracy: 0.9240 - val_loss: 0.2388 - val_accuracy: 0.9131
#
# Epoch 27/30
# 17/17 - 6s - loss: 0.2116 - accuracy: 0.9247 - val_loss: 0.2514 - val_accuracy: 0.9191
#
# Epoch 28/30
# 17/17 - 6s - loss: 0.2217 - accuracy: 0.9237 - val_loss: 0.2701 - val_accuracy: 0.9025
#
# Epoch 29/30
# 17/17 - 6s - loss: 0.2225 - accuracy: 0.9231 - val_loss: 0.2562 - val_accuracy: 0.9082
#
# Epoch 30/30
# 17/17 - 6s - loss: 0.2199 - accuracy: 0.9254 - val_loss: 0.2634 - val_accuracy: 0.9079
#
# Best validation acc of epoch:
# 0.9190523028373718
# froz=
# 10
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 6s - loss: 1.2447 - accuracy: 0.4017 - val_loss: 1.0945 - val_accuracy: 0.3265
#
# Epoch 2/30
# 17/17 - 5s - loss: 1.0592 - accuracy: 0.4271 - val_loss: 1.0921 - val_accuracy: 0.4102
#
# Epoch 3/30
# 17/17 - 5s - loss: 1.0610 - accuracy: 0.4487 - val_loss: 0.9741 - val_accuracy: 0.5758
#
# Epoch 4/30
# 17/17 - 5s - loss: 0.9713 - accuracy: 0.5275 - val_loss: 0.8891 - val_accuracy: 0.5247
#
# Epoch 5/30
# 17/17 - 5s - loss: 0.9056 - accuracy: 0.5668 - val_loss: 0.7913 - val_accuracy: 0.6377
#
# Epoch 6/30
# 17/17 - 5s - loss: 0.8327 - accuracy: 0.6261 - val_loss: 0.7195 - val_accuracy: 0.6757
#
# Epoch 7/30
# 17/17 - 5s - loss: 0.7577 - accuracy: 0.6470 - val_loss: 0.6200 - val_accuracy: 0.6851
#
# Epoch 8/30
# 17/17 - 6s - loss: 0.7024 - accuracy: 0.6674 - val_loss: 0.6540 - val_accuracy: 0.6792
#
# Epoch 9/30
# 17/17 - 5s - loss: 0.6874 - accuracy: 0.6950 - val_loss: 0.6252 - val_accuracy: 0.7604
#
# Epoch 10/30
# 17/17 - 5s - loss: 0.6399 - accuracy: 0.7576 - val_loss: 0.5995 - val_accuracy: 0.8223
#
# Epoch 11/30
# 17/17 - 6s - loss: 0.5696 - accuracy: 0.8082 - val_loss: 0.5522 - val_accuracy: 0.8455
#
# Epoch 12/30
# 17/17 - 5s - loss: 0.5183 - accuracy: 0.8377 - val_loss: 0.4380 - val_accuracy: 0.8707
#
# Epoch 13/30
# 17/17 - 5s - loss: 0.4689 - accuracy: 0.8459 - val_loss: 0.3719 - val_accuracy: 0.8591
#
# Epoch 14/30
# 17/17 - 6s - loss: 0.4268 - accuracy: 0.8619 - val_loss: 0.3272 - val_accuracy: 0.8813
#
# Epoch 15/30
# 17/17 - 6s - loss: 0.3975 - accuracy: 0.8727 - val_loss: 0.4193 - val_accuracy: 0.8248
#
# Epoch 16/30
# 17/17 - 6s - loss: 0.4171 - accuracy: 0.8664 - val_loss: 0.3091 - val_accuracy: 0.8963
#
# Epoch 17/30
# 17/17 - 5s - loss: 0.3498 - accuracy: 0.8918 - val_loss: 0.3258 - val_accuracy: 0.8944
#
# Epoch 18/30
# 17/17 - 5s - loss: 0.3327 - accuracy: 0.8951 - val_loss: 0.4357 - val_accuracy: 0.8813
#
# Epoch 19/30
# 17/17 - 5s - loss: 0.3202 - accuracy: 0.9013 - val_loss: 0.3326 - val_accuracy: 0.8936
#
# Epoch 20/30
# 17/17 - 6s - loss: 0.3082 - accuracy: 0.9028 - val_loss: 0.3321 - val_accuracy: 0.9075
#
# Epoch 21/30
# 17/17 - 5s - loss: 0.2794 - accuracy: 0.9129 - val_loss: 0.2903 - val_accuracy: 0.9104
#
# Epoch 22/30
# 17/17 - 5s - loss: 0.2678 - accuracy: 0.9160 - val_loss: 0.2964 - val_accuracy: 0.9136
#
# Epoch 23/30
# 17/17 - 5s - loss: 0.2541 - accuracy: 0.9196 - val_loss: 0.2593 - val_accuracy: 0.9079
#
# Epoch 24/30
# 17/17 - 6s - loss: 0.2510 - accuracy: 0.9216 - val_loss: 0.2710 - val_accuracy: 0.9166
#
# Epoch 25/30
# 17/17 - 6s - loss: 0.2506 - accuracy: 0.9212 - val_loss: 0.3881 - val_accuracy: 0.8828
#
# Epoch 26/30
# 17/17 - 5s - loss: 0.3037 - accuracy: 0.9062 - val_loss: 0.2834 - val_accuracy: 0.9089
#
# Epoch 27/30
# 17/17 - 6s - loss: 0.2457 - accuracy: 0.9239 - val_loss: 0.3736 - val_accuracy: 0.9171
#
# Epoch 28/30
# 17/17 - 6s - loss: 0.2459 - accuracy: 0.9241 - val_loss: 0.2569 - val_accuracy: 0.9092
#
# Epoch 29/30
# 17/17 - 6s - loss: 0.2123 - accuracy: 0.9312 - val_loss: 0.2741 - val_accuracy: 0.9097
#
# Epoch 30/30
# 17/17 - 5s - loss: 0.2089 - accuracy: 0.9332 - val_loss: 0.2954 - val_accuracy: 0.8956
#
# Best validation acc of epoch:
# 0.9170779585838318
# froz=
# 17
# dense_layers=
# 2
# Epoch 1/30
# 17/17 - 8s - loss: 4.8744 - accuracy: 0.3920 - val_loss: 1.0494 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 8s - loss: 1.0681 - accuracy: 0.4380 - val_loss: 1.0443 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 8s - loss: 1.0653 - accuracy: 0.4488 - val_loss: 1.0510 - val_accuracy: 0.5155
#
# Epoch 4/30
# 17/17 - 8s - loss: 1.0524 - accuracy: 0.4571 - val_loss: 1.0240 - val_accuracy: 0.4699
#
# Epoch 5/30
# 17/17 - 8s - loss: 1.0291 - accuracy: 0.4951 - val_loss: 0.9792 - val_accuracy: 0.5679
#
# Epoch 6/30
# 17/17 - 8s - loss: 1.0119 - accuracy: 0.5233 - val_loss: 0.9476 - val_accuracy: 0.5471
#
# Epoch 7/30
# 17/17 - 8s - loss: 0.9836 - accuracy: 0.5516 - val_loss: 0.9037 - val_accuracy: 0.6007
#
# Epoch 8/30
# 17/17 - 8s - loss: 0.9693 - accuracy: 0.5748 - val_loss: 1.0353 - val_accuracy: 0.5217
#
# Epoch 9/30
# 17/17 - 8s - loss: 0.9821 - accuracy: 0.5602 - val_loss: 0.8603 - val_accuracy: 0.6081
#
# Epoch 10/30
# 17/17 - 8s - loss: 0.9058 - accuracy: 0.6143 - val_loss: 0.7903 - val_accuracy: 0.6407
#
# Epoch 11/30
# 17/17 - 8s - loss: 0.8375 - accuracy: 0.6467 - val_loss: 0.7297 - val_accuracy: 0.6967
#
# Epoch 12/30
# 17/17 - 8s - loss: 0.7743 - accuracy: 0.6887 - val_loss: 0.8039 - val_accuracy: 0.6340
#
# Epoch 13/30
# 17/17 - 8s - loss: 0.7321 - accuracy: 0.7272 - val_loss: 0.5700 - val_accuracy: 0.7947
#
# Epoch 14/30
# 17/17 - 8s - loss: 0.6447 - accuracy: 0.7759 - val_loss: 0.5778 - val_accuracy: 0.7618
#
# Epoch 15/30
# 17/17 - 8s - loss: 0.5725 - accuracy: 0.8057 - val_loss: 0.4299 - val_accuracy: 0.8391
#
# Epoch 16/30
# 17/17 - 8s - loss: 0.5878 - accuracy: 0.7993 - val_loss: 0.5234 - val_accuracy: 0.8097
#
# Epoch 17/30
# 17/17 - 8s - loss: 0.5350 - accuracy: 0.8256 - val_loss: 0.3931 - val_accuracy: 0.8598
#
# Epoch 18/30
# 17/17 - 8s - loss: 0.5216 - accuracy: 0.8320 - val_loss: 0.4235 - val_accuracy: 0.8450
#
# Epoch 19/30
# 17/17 - 8s - loss: 0.4727 - accuracy: 0.8551 - val_loss: 0.3546 - val_accuracy: 0.8781
#
# Epoch 20/30
# 17/17 - 8s - loss: 0.4273 - accuracy: 0.8701 - val_loss: 0.3369 - val_accuracy: 0.8838
#
# Epoch 21/30
# 17/17 - 8s - loss: 0.4328 - accuracy: 0.8670 - val_loss: 0.3406 - val_accuracy: 0.8788
#
# Epoch 22/30
# 17/17 - 8s - loss: 0.4007 - accuracy: 0.8760 - val_loss: 0.3165 - val_accuracy: 0.8867
#
# Epoch 23/30
# 17/17 - 8s - loss: 0.3657 - accuracy: 0.8907 - val_loss: 0.3015 - val_accuracy: 0.8936
#
# Epoch 24/30
# 17/17 - 8s - loss: 0.3811 - accuracy: 0.8849 - val_loss: 0.3197 - val_accuracy: 0.8894
#
# Epoch 25/30
# 17/17 - 8s - loss: 0.3530 - accuracy: 0.8934 - val_loss: 0.2937 - val_accuracy: 0.8976
#
# Epoch 26/30
# 17/17 - 8s - loss: 0.3369 - accuracy: 0.8994 - val_loss: 0.3265 - val_accuracy: 0.8870
#
# Epoch 27/30
# 17/17 - 8s - loss: 0.3412 - accuracy: 0.8957 - val_loss: 0.4340 - val_accuracy: 0.8495
#
# Epoch 28/30
# 17/17 - 8s - loss: 0.3442 - accuracy: 0.8958 - val_loss: 0.3007 - val_accuracy: 0.8976
#
# Epoch 29/30
# 17/17 - 8s - loss: 0.3236 - accuracy: 0.9034 - val_loss: 0.2830 - val_accuracy: 0.8981
#
# Epoch 30/30
# 17/17 - 8s - loss: 0.3056 - accuracy: 0.9077 - val_loss: 0.2619 - val_accuracy: 0.9084
#
# Best validation acc of epoch:
# 0.9084402918815613
# froz=
# 8
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 5s - loss: 1.9712 - accuracy: 0.3380 - val_loss: 1.0688 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 5s - loss: 1.0181 - accuracy: 0.4792 - val_loss: 0.8682 - val_accuracy: 0.5676
#
# Epoch 3/30
# 17/17 - 5s - loss: 0.8318 - accuracy: 0.6061 - val_loss: 0.6719 - val_accuracy: 0.6987
#
# Epoch 4/30
# 17/17 - 5s - loss: 0.7819 - accuracy: 0.6739 - val_loss: 2.0042 - val_accuracy: 0.4692
#
# Epoch 5/30
# 17/17 - 5s - loss: 0.7685 - accuracy: 0.6752 - val_loss: 0.5435 - val_accuracy: 0.7771
#
# Epoch 6/30
# 17/17 - 5s - loss: 0.5041 - accuracy: 0.8010 - val_loss: 0.4510 - val_accuracy: 0.8196
#
# Epoch 7/30
# 17/17 - 5s - loss: 0.4398 - accuracy: 0.8304 - val_loss: 0.4140 - val_accuracy: 0.8356
#
# Epoch 8/30
# 17/17 - 5s - loss: 0.4069 - accuracy: 0.8453 - val_loss: 0.3931 - val_accuracy: 0.8492
#
# Epoch 9/30
# 17/17 - 5s - loss: 0.3657 - accuracy: 0.8631 - val_loss: 0.3749 - val_accuracy: 0.8603
#
# Epoch 10/30
# 17/17 - 5s - loss: 0.3483 - accuracy: 0.8721 - val_loss: 0.3279 - val_accuracy: 0.8788
#
# Epoch 11/30
# 17/17 - 5s - loss: 0.3266 - accuracy: 0.8788 - val_loss: 0.3420 - val_accuracy: 0.8685
#
# Epoch 12/30
# 17/17 - 5s - loss: 0.3437 - accuracy: 0.8737 - val_loss: 0.3120 - val_accuracy: 0.8892
#
# Epoch 13/30
# 17/17 - 5s - loss: 0.3181 - accuracy: 0.8858 - val_loss: 0.3631 - val_accuracy: 0.8697
#
# Epoch 14/30
# 17/17 - 5s - loss: 0.2875 - accuracy: 0.8966 - val_loss: 0.2974 - val_accuracy: 0.8904
#
# Epoch 15/30
# 17/17 - 5s - loss: 0.2703 - accuracy: 0.9021 - val_loss: 0.3190 - val_accuracy: 0.8835
#
# Epoch 16/30
# 17/17 - 5s - loss: 0.2624 - accuracy: 0.9041 - val_loss: 0.2613 - val_accuracy: 0.9040
#
# Epoch 17/30
# 17/17 - 5s - loss: 0.2465 - accuracy: 0.9112 - val_loss: 0.2490 - val_accuracy: 0.9060
#
# Epoch 18/30
# 17/17 - 5s - loss: 0.2319 - accuracy: 0.9158 - val_loss: 0.2653 - val_accuracy: 0.8946
#
# Epoch 19/30
# 17/17 - 5s - loss: 0.2357 - accuracy: 0.9141 - val_loss: 0.2415 - val_accuracy: 0.9149
#
# Epoch 20/30
# 17/17 - 5s - loss: 0.2148 - accuracy: 0.9221 - val_loss: 0.2411 - val_accuracy: 0.9129
#
# Epoch 21/30
# 17/17 - 5s - loss: 0.2170 - accuracy: 0.9217 - val_loss: 0.2526 - val_accuracy: 0.9042
#
# Epoch 22/30
# 17/17 - 5s - loss: 0.2172 - accuracy: 0.9214 - val_loss: 0.2415 - val_accuracy: 0.9149
#
# Epoch 23/30
# 17/17 - 5s - loss: 0.1965 - accuracy: 0.9305 - val_loss: 0.2769 - val_accuracy: 0.8993
#
# Epoch 24/30
# 17/17 - 5s - loss: 0.1973 - accuracy: 0.9283 - val_loss: 0.2258 - val_accuracy: 0.9213
#
# Epoch 25/30
# 17/17 - 5s - loss: 0.1853 - accuracy: 0.9336 - val_loss: 0.3942 - val_accuracy: 0.8731
#
# Epoch 26/30
# 17/17 - 5s - loss: 0.3268 - accuracy: 0.8813 - val_loss: 0.3216 - val_accuracy: 0.9005
#
# Epoch 27/30
# 17/17 - 5s - loss: 0.2228 - accuracy: 0.9208 - val_loss: 0.2383 - val_accuracy: 0.9109
#
# Epoch 28/30
# 17/17 - 5s - loss: 0.1857 - accuracy: 0.9339 - val_loss: 0.2424 - val_accuracy: 0.9151
#
# Epoch 29/30
# 17/17 - 5s - loss: 0.1725 - accuracy: 0.9390 - val_loss: 0.2260 - val_accuracy: 0.9163
#
# Epoch 30/30
# 17/17 - 5s - loss: 0.1685 - accuracy: 0.9399 - val_loss: 0.2286 - val_accuracy: 0.9188
#
# Best validation acc of epoch:
# 0.9212734699249268
# froz=
# 12
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 6s - loss: 1.7273 - accuracy: 0.3749 - val_loss: 1.0587 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 6s - loss: 1.0793 - accuracy: 0.4204 - val_loss: 1.0713 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 6s - loss: 1.0653 - accuracy: 0.4411 - val_loss: 1.0507 - val_accuracy: 0.4640
#
# Epoch 4/30
# 17/17 - 6s - loss: 1.0511 - accuracy: 0.4366 - val_loss: 0.9807 - val_accuracy: 0.4640
#
# Epoch 5/30
# 17/17 - 6s - loss: 0.9933 - accuracy: 0.4472 - val_loss: 0.9314 - val_accuracy: 0.4640
#
# Epoch 6/30
# 17/17 - 6s - loss: 0.9760 - accuracy: 0.4780 - val_loss: 0.9658 - val_accuracy: 0.5052
#
# Epoch 7/30
# 17/17 - 6s - loss: 0.9050 - accuracy: 0.5465 - val_loss: 0.8068 - val_accuracy: 0.6436
#
# Epoch 8/30
# 17/17 - 6s - loss: 0.8477 - accuracy: 0.6082 - val_loss: 0.7865 - val_accuracy: 0.6651
#
# Epoch 9/30
# 17/17 - 6s - loss: 0.7835 - accuracy: 0.6459 - val_loss: 0.6608 - val_accuracy: 0.7019
#
# Epoch 10/30
# 17/17 - 6s - loss: 0.7524 - accuracy: 0.6677 - val_loss: 0.6455 - val_accuracy: 0.7557
#
# Epoch 11/30
# 17/17 - 6s - loss: 0.7453 - accuracy: 0.6769 - val_loss: 0.6598 - val_accuracy: 0.6587
#
# Epoch 12/30
# 17/17 - 6s - loss: 0.6926 - accuracy: 0.6951 - val_loss: 0.5914 - val_accuracy: 0.7774
#
# Epoch 13/30
# 17/17 - 6s - loss: 0.6667 - accuracy: 0.7289 - val_loss: 0.5672 - val_accuracy: 0.7823
#
# Epoch 14/30
# 17/17 - 6s - loss: 0.5932 - accuracy: 0.7847 - val_loss: 0.4807 - val_accuracy: 0.8509
#
# Epoch 15/30
# 17/17 - 6s - loss: 0.5595 - accuracy: 0.8065 - val_loss: 0.5093 - val_accuracy: 0.8292
#
# Epoch 16/30
# 17/17 - 6s - loss: 0.4926 - accuracy: 0.8392 - val_loss: 0.4251 - val_accuracy: 0.8522
#
# Epoch 17/30
# 17/17 - 6s - loss: 0.4448 - accuracy: 0.8648 - val_loss: 0.4115 - val_accuracy: 0.8544
#
# Epoch 18/30
# 17/17 - 6s - loss: 0.4216 - accuracy: 0.8670 - val_loss: 0.3643 - val_accuracy: 0.8672
#
# Epoch 19/30
# 17/17 - 6s - loss: 0.4497 - accuracy: 0.8578 - val_loss: 0.4204 - val_accuracy: 0.8450
#
# Epoch 20/30
# 17/17 - 6s - loss: 0.4217 - accuracy: 0.8688 - val_loss: 0.3751 - val_accuracy: 0.8569
#
# Epoch 21/30
# 17/17 - 6s - loss: 0.4002 - accuracy: 0.8725 - val_loss: 0.3833 - val_accuracy: 0.8591
#
# Epoch 22/30
# 17/17 - 6s - loss: 0.3736 - accuracy: 0.8839 - val_loss: 0.3193 - val_accuracy: 0.8850
#
# Epoch 23/30
# 17/17 - 6s - loss: 0.3806 - accuracy: 0.8801 - val_loss: 0.3241 - val_accuracy: 0.8939
#
# Epoch 24/30
# 17/17 - 6s - loss: 0.3254 - accuracy: 0.8996 - val_loss: 0.2912 - val_accuracy: 0.9000
#
# Epoch 25/30
# 17/17 - 6s - loss: 0.3110 - accuracy: 0.9062 - val_loss: 0.2706 - val_accuracy: 0.9050
#
# Epoch 26/30
# 17/17 - 6s - loss: 0.2934 - accuracy: 0.9080 - val_loss: 0.2672 - val_accuracy: 0.9018
#
# Epoch 27/30
# 17/17 - 6s - loss: 0.2778 - accuracy: 0.9127 - val_loss: 0.2777 - val_accuracy: 0.9075
#
# Epoch 28/30
# 17/17 - 6s - loss: 0.3069 - accuracy: 0.9062 - val_loss: 0.2794 - val_accuracy: 0.9010
#
# Epoch 29/30
# 17/17 - 6s - loss: 0.2837 - accuracy: 0.9104 - val_loss: 0.2996 - val_accuracy: 0.9047
#
# Epoch 30/30
# 17/17 - 6s - loss: 0.2712 - accuracy: 0.9158 - val_loss: 0.3288 - val_accuracy: 0.9042
#
# Best validation acc of epoch:
# 0.9074531197547913
# froz=
# 17
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 8s - loss: 1.1594 - accuracy: 0.3993 - val_loss: 1.0751 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 8s - loss: 1.0723 - accuracy: 0.4286 - val_loss: 1.0450 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 8s - loss: 1.0717 - accuracy: 0.4389 - val_loss: 1.0666 - val_accuracy: 0.4640
#
# Epoch 4/30
# 17/17 - 8s - loss: 1.0531 - accuracy: 0.4505 - val_loss: 1.0676 - val_accuracy: 0.4640
#
# Epoch 5/30
# 17/17 - 8s - loss: 1.0580 - accuracy: 0.4488 - val_loss: 1.0668 - val_accuracy: 0.4640
#
# Epoch 6/30
# 17/17 - 8s - loss: 1.0666 - accuracy: 0.4513 - val_loss: 1.0642 - val_accuracy: 0.4640
#
# Epoch 7/30
# 17/17 - 8s - loss: 1.0645 - accuracy: 0.4534 - val_loss: 1.0721 - val_accuracy: 0.4640
#
# Epoch 8/30
# 17/17 - 8s - loss: 1.0657 - accuracy: 0.4568 - val_loss: 1.0613 - val_accuracy: 0.4640
#
# Epoch 9/30
# 17/17 - 8s - loss: 1.0615 - accuracy: 0.4567 - val_loss: 1.0567 - val_accuracy: 0.4640
#
# Epoch 10/30
# 17/17 - 8s - loss: 1.0581 - accuracy: 0.4573 - val_loss: 1.0514 - val_accuracy: 0.4640
#
# Epoch 11/30
# 17/17 - 8s - loss: 1.0227 - accuracy: 0.4567 - val_loss: 0.9397 - val_accuracy: 0.4640
#
# Epoch 12/30
# 17/17 - 8s - loss: 1.1403 - accuracy: 0.4555 - val_loss: 1.0703 - val_accuracy: 0.4640
#
# Epoch 13/30
# 17/17 - 8s - loss: 1.0804 - accuracy: 0.4558 - val_loss: 1.0556 - val_accuracy: 0.4640
#
# Epoch 14/30
# 17/17 - 8s - loss: 1.0479 - accuracy: 0.4497 - val_loss: 0.9699 - val_accuracy: 0.4640
#
# Epoch 15/30
# 17/17 - 8s - loss: 1.0842 - accuracy: 0.4531 - val_loss: 1.0675 - val_accuracy: 0.4640
#
# Epoch 16/30
# 17/17 - 8s - loss: 1.0664 - accuracy: 0.4573 - val_loss: 1.0609 - val_accuracy: 0.4640
#
# Epoch 17/30
# 17/17 - 8s - loss: 1.0604 - accuracy: 0.4573 - val_loss: 1.0560 - val_accuracy: 0.4640
#
# Epoch 18/30
# 17/17 - 8s - loss: 1.0575 - accuracy: 0.4573 - val_loss: 1.0533 - val_accuracy: 0.4640
#
# Epoch 19/30
# 17/17 - 8s - loss: 1.0570 - accuracy: 0.4573 - val_loss: 1.0522 - val_accuracy: 0.4640
#
# Epoch 20/30
# 17/17 - 8s - loss: 1.0557 - accuracy: 0.4573 - val_loss: 1.0517 - val_accuracy: 0.4640
#
# Epoch 21/30
# 17/17 - 8s - loss: 1.0559 - accuracy: 0.4573 - val_loss: 1.0515 - val_accuracy: 0.4640
#
# Epoch 22/30
# 17/17 - 8s - loss: 1.0553 - accuracy: 0.4573 - val_loss: 1.0516 - val_accuracy: 0.4640
#
# Epoch 23/30
# 17/17 - 8s - loss: 1.0560 - accuracy: 0.4573 - val_loss: 1.0516 - val_accuracy: 0.4640
#
# Epoch 24/30
# 17/17 - 8s - loss: 1.0562 - accuracy: 0.4573 - val_loss: 1.0516 - val_accuracy: 0.4640
#
# Epoch 25/30
# 17/17 - 8s - loss: 1.0553 - accuracy: 0.4573 - val_loss: 1.0516 - val_accuracy: 0.4640
#
# Epoch 26/30
# 17/17 - 8s - loss: 1.0552 - accuracy: 0.4573 - val_loss: 1.0516 - val_accuracy: 0.4640
#
# Epoch 27/30
# 17/17 - 8s - loss: 1.0558 - accuracy: 0.4573 - val_loss: 1.0515 - val_accuracy: 0.4640
#
# Epoch 28/30
# 17/17 - 8s - loss: 1.0553 - accuracy: 0.4573 - val_loss: 1.0515 - val_accuracy: 0.4640
#
# Epoch 29/30
# 17/17 - 8s - loss: 1.0549 - accuracy: 0.4573 - val_loss: 1.0515 - val_accuracy: 0.4640
#
# Epoch 30/30
# 17/17 - 8s - loss: 1.0550 - accuracy: 0.4573 - val_loss: 1.0514 - val_accuracy: 0.4640
#
# Best validation acc of epoch:
# 0.4639683961868286
# froz=
# 1
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 4s - loss: 0.8285 - accuracy: 0.6364 - val_loss: 0.5754 - val_accuracy: 0.7754
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.5915 - accuracy: 0.7730 - val_loss: 0.4883 - val_accuracy: 0.8068
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.5179 - accuracy: 0.8023 - val_loss: 0.4517 - val_accuracy: 0.8233
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.4729 - accuracy: 0.8194 - val_loss: 0.4241 - val_accuracy: 0.8337
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.4478 - accuracy: 0.8299 - val_loss: 0.4000 - val_accuracy: 0.8423
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.4237 - accuracy: 0.8384 - val_loss: 0.3860 - val_accuracy: 0.8492
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.4071 - accuracy: 0.8438 - val_loss: 0.4037 - val_accuracy: 0.8495
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.4026 - accuracy: 0.8463 - val_loss: 0.3718 - val_accuracy: 0.8561
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.3870 - accuracy: 0.8539 - val_loss: 0.3584 - val_accuracy: 0.8611
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.3719 - accuracy: 0.8585 - val_loss: 0.3522 - val_accuracy: 0.8638
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.3649 - accuracy: 0.8599 - val_loss: 0.3627 - val_accuracy: 0.8625
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.3575 - accuracy: 0.8658 - val_loss: 0.3447 - val_accuracy: 0.8670
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.3453 - accuracy: 0.8693 - val_loss: 0.3422 - val_accuracy: 0.8685
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.3425 - accuracy: 0.8733 - val_loss: 0.3364 - val_accuracy: 0.8734
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.3366 - accuracy: 0.8707 - val_loss: 0.3351 - val_accuracy: 0.8682
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.3335 - accuracy: 0.8745 - val_loss: 0.3322 - val_accuracy: 0.8714
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.3220 - accuracy: 0.8796 - val_loss: 0.3263 - val_accuracy: 0.8736
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.3239 - accuracy: 0.8790 - val_loss: 0.3409 - val_accuracy: 0.8704
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.3145 - accuracy: 0.8806 - val_loss: 0.3326 - val_accuracy: 0.8729
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.3194 - accuracy: 0.8791 - val_loss: 0.3411 - val_accuracy: 0.8729
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.3125 - accuracy: 0.8832 - val_loss: 0.3291 - val_accuracy: 0.8754
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.3097 - accuracy: 0.8829 - val_loss: 0.3264 - val_accuracy: 0.8739
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.3017 - accuracy: 0.8865 - val_loss: 0.3192 - val_accuracy: 0.8796
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.3018 - accuracy: 0.8857 - val_loss: 0.3226 - val_accuracy: 0.8746
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.3074 - accuracy: 0.8823 - val_loss: 0.3178 - val_accuracy: 0.8815
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.2982 - accuracy: 0.8868 - val_loss: 0.3137 - val_accuracy: 0.8833
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.2928 - accuracy: 0.8938 - val_loss: 0.3211 - val_accuracy: 0.8796
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.2952 - accuracy: 0.8881 - val_loss: 0.3275 - val_accuracy: 0.8756
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.2937 - accuracy: 0.8893 - val_loss: 0.3202 - val_accuracy: 0.8798
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.2864 - accuracy: 0.8938 - val_loss: 0.3209 - val_accuracy: 0.8801
#
# Best validation acc of epoch:
# 0.8832675218582153
# froz=
# 3
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 4s - loss: 0.9381 - accuracy: 0.5864 - val_loss: 0.5938 - val_accuracy: 0.7720
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.5394 - accuracy: 0.7944 - val_loss: 0.4435 - val_accuracy: 0.8263
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.4385 - accuracy: 0.8380 - val_loss: 0.3699 - val_accuracy: 0.8574
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.3771 - accuracy: 0.8632 - val_loss: 0.3447 - val_accuracy: 0.8709
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.3412 - accuracy: 0.8766 - val_loss: 0.3231 - val_accuracy: 0.8776
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.3280 - accuracy: 0.8822 - val_loss: 0.3061 - val_accuracy: 0.8860
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.2896 - accuracy: 0.8963 - val_loss: 0.3452 - val_accuracy: 0.8707
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.2926 - accuracy: 0.8933 - val_loss: 0.3226 - val_accuracy: 0.8823
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.2770 - accuracy: 0.8991 - val_loss: 0.3064 - val_accuracy: 0.8899
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.2445 - accuracy: 0.9117 - val_loss: 0.2924 - val_accuracy: 0.8857
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.2283 - accuracy: 0.9176 - val_loss: 0.2891 - val_accuracy: 0.8961
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.2252 - accuracy: 0.9197 - val_loss: 0.2770 - val_accuracy: 0.8963
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.2248 - accuracy: 0.9185 - val_loss: 0.3719 - val_accuracy: 0.8667
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.2326 - accuracy: 0.9161 - val_loss: 0.2852 - val_accuracy: 0.8936
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.2054 - accuracy: 0.9247 - val_loss: 0.2844 - val_accuracy: 0.8986
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.1819 - accuracy: 0.9347 - val_loss: 0.2843 - val_accuracy: 0.8909
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.1791 - accuracy: 0.9358 - val_loss: 0.3673 - val_accuracy: 0.8860
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.1816 - accuracy: 0.9366 - val_loss: 0.2719 - val_accuracy: 0.9060
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.1562 - accuracy: 0.9458 - val_loss: 0.3041 - val_accuracy: 0.8996
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.1568 - accuracy: 0.9443 - val_loss: 0.2857 - val_accuracy: 0.8993
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.1343 - accuracy: 0.9529 - val_loss: 0.2994 - val_accuracy: 0.9092
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.1211 - accuracy: 0.9586 - val_loss: 0.3174 - val_accuracy: 0.8996
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.1173 - accuracy: 0.9594 - val_loss: 0.3788 - val_accuracy: 0.8885
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.1268 - accuracy: 0.9550 - val_loss: 0.3788 - val_accuracy: 0.8941
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.1110 - accuracy: 0.9600 - val_loss: 0.3347 - val_accuracy: 0.9052
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.0988 - accuracy: 0.9661 - val_loss: 0.3166 - val_accuracy: 0.9075
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.0786 - accuracy: 0.9742 - val_loss: 0.4096 - val_accuracy: 0.8934
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.1149 - accuracy: 0.9587 - val_loss: 0.3357 - val_accuracy: 0.9025
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.1054 - accuracy: 0.9626 - val_loss: 0.3747 - val_accuracy: 0.8963
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.0947 - accuracy: 0.9685 - val_loss: 0.4099 - val_accuracy: 0.8825
#
# Best validation acc of epoch:
# 0.9091806411743164
# froz=
# 10
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 6s - loss: 5.9719 - accuracy: 0.4110 - val_loss: 1.0442 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 5s - loss: 1.0509 - accuracy: 0.4608 - val_loss: 1.0356 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 5s - loss: 1.0294 - accuracy: 0.4573 - val_loss: 0.9800 - val_accuracy: 0.4642
#
# Epoch 4/30
# 17/17 - 5s - loss: 0.9495 - accuracy: 0.5439 - val_loss: 0.8244 - val_accuracy: 0.6111
#
# Epoch 5/30
# 17/17 - 5s - loss: 0.8167 - accuracy: 0.6162 - val_loss: 0.7836 - val_accuracy: 0.6392
#
# Epoch 6/30
# 17/17 - 5s - loss: 0.7172 - accuracy: 0.6876 - val_loss: 1.0966 - val_accuracy: 0.4825
#
# Epoch 7/30
# 17/17 - 5s - loss: 0.7072 - accuracy: 0.6881 - val_loss: 0.5879 - val_accuracy: 0.7764
#
# Epoch 8/30
# 17/17 - 5s - loss: 0.8082 - accuracy: 0.6534 - val_loss: 0.7514 - val_accuracy: 0.6567
#
# Epoch 9/30
# 17/17 - 5s - loss: 0.6793 - accuracy: 0.6969 - val_loss: 0.5869 - val_accuracy: 0.7762
#
# Epoch 10/30
# 17/17 - 5s - loss: 0.5634 - accuracy: 0.7760 - val_loss: 0.5673 - val_accuracy: 0.7897
#
# Epoch 11/30
# 17/17 - 5s - loss: 0.4799 - accuracy: 0.8164 - val_loss: 0.4416 - val_accuracy: 0.8309
#
# Epoch 12/30
# 17/17 - 5s - loss: 0.4588 - accuracy: 0.8271 - val_loss: 0.4576 - val_accuracy: 0.8142
#
# Epoch 13/30
# 17/17 - 5s - loss: 0.4101 - accuracy: 0.8494 - val_loss: 0.4437 - val_accuracy: 0.8374
#
# Epoch 14/30
# 17/17 - 5s - loss: 0.3976 - accuracy: 0.8519 - val_loss: 0.4790 - val_accuracy: 0.8255
#
# Epoch 15/30
# 17/17 - 5s - loss: 0.3851 - accuracy: 0.8558 - val_loss: 0.3747 - val_accuracy: 0.8628
#
# Epoch 16/30
# 17/17 - 5s - loss: 0.3427 - accuracy: 0.8757 - val_loss: 0.3362 - val_accuracy: 0.8771
#
# Epoch 17/30
# 17/17 - 6s - loss: 0.3406 - accuracy: 0.8754 - val_loss: 0.3233 - val_accuracy: 0.8776
#
# Epoch 18/30
# 17/17 - 5s - loss: 0.3033 - accuracy: 0.8870 - val_loss: 0.2954 - val_accuracy: 0.8845
#
# Epoch 19/30
# 17/17 - 6s - loss: 0.2881 - accuracy: 0.8950 - val_loss: 0.2916 - val_accuracy: 0.8963
#
# Epoch 20/30
# 17/17 - 5s - loss: 0.2659 - accuracy: 0.9038 - val_loss: 0.3043 - val_accuracy: 0.8850
#
# Epoch 21/30
# 17/17 - 5s - loss: 0.2963 - accuracy: 0.8896 - val_loss: 0.2774 - val_accuracy: 0.8971
#
# Epoch 22/30
# 17/17 - 5s - loss: 0.2599 - accuracy: 0.9026 - val_loss: 0.2663 - val_accuracy: 0.8991
#
# Epoch 23/30
# 17/17 - 5s - loss: 0.2431 - accuracy: 0.9114 - val_loss: 0.2555 - val_accuracy: 0.9082
#
# Epoch 24/30
# 17/17 - 5s - loss: 0.2361 - accuracy: 0.9135 - val_loss: 0.2894 - val_accuracy: 0.8882
#
# Epoch 25/30
# 17/17 - 5s - loss: 0.2734 - accuracy: 0.9007 - val_loss: 0.3075 - val_accuracy: 0.8852
#
# Epoch 26/30
# 17/17 - 5s - loss: 0.2473 - accuracy: 0.9086 - val_loss: 0.2654 - val_accuracy: 0.9050
#
# Epoch 27/30
# 17/17 - 5s - loss: 0.2276 - accuracy: 0.9184 - val_loss: 0.2630 - val_accuracy: 0.9013
#
# Epoch 28/30
# 17/17 - 5s - loss: 0.2208 - accuracy: 0.9191 - val_loss: 0.2450 - val_accuracy: 0.9082
#
# Epoch 29/30
# 17/17 - 5s - loss: 0.2035 - accuracy: 0.9256 - val_loss: 0.2473 - val_accuracy: 0.9072
#
# Epoch 30/30
# 17/17 - 5s - loss: 0.2078 - accuracy: 0.9246 - val_loss: 0.2422 - val_accuracy: 0.9126
#
# Best validation acc of epoch:
# 0.9126357436180115
# froz=
# 3
# dense_layers=
# 3
# Epoch 1/30
# 17/17 - 4s - loss: 1.0327 - accuracy: 0.4965 - val_loss: 0.8065 - val_accuracy: 0.7646
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.8094 - accuracy: 0.6373 - val_loss: 0.5955 - val_accuracy: 0.8174
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.6882 - accuracy: 0.7296 - val_loss: 0.4651 - val_accuracy: 0.8337
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.5511 - accuracy: 0.8028 - val_loss: 0.3867 - val_accuracy: 0.8618
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.5025 - accuracy: 0.8282 - val_loss: 0.3640 - val_accuracy: 0.8593
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.4404 - accuracy: 0.8496 - val_loss: 0.3404 - val_accuracy: 0.8796
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.4063 - accuracy: 0.8627 - val_loss: 0.3382 - val_accuracy: 0.8643
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.3884 - accuracy: 0.8721 - val_loss: 0.3645 - val_accuracy: 0.8722
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.3626 - accuracy: 0.8835 - val_loss: 0.3530 - val_accuracy: 0.8828
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.3447 - accuracy: 0.8839 - val_loss: 0.3391 - val_accuracy: 0.8845
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.3092 - accuracy: 0.8988 - val_loss: 0.3383 - val_accuracy: 0.8840
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.2898 - accuracy: 0.9042 - val_loss: 0.3220 - val_accuracy: 0.8931
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.3243 - accuracy: 0.8926 - val_loss: 0.3091 - val_accuracy: 0.8882
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.2877 - accuracy: 0.9069 - val_loss: 0.2852 - val_accuracy: 0.8904
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.2686 - accuracy: 0.9118 - val_loss: 0.4608 - val_accuracy: 0.8628
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.2817 - accuracy: 0.9079 - val_loss: 0.2906 - val_accuracy: 0.8924
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.2518 - accuracy: 0.9179 - val_loss: 0.2975 - val_accuracy: 0.9010
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.2303 - accuracy: 0.9248 - val_loss: 0.2815 - val_accuracy: 0.9045
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.2177 - accuracy: 0.9290 - val_loss: 0.3492 - val_accuracy: 0.8988
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.2044 - accuracy: 0.9325 - val_loss: 0.3077 - val_accuracy: 0.9023
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.2062 - accuracy: 0.9353 - val_loss: 0.3185 - val_accuracy: 0.8986
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.1883 - accuracy: 0.9389 - val_loss: 0.3633 - val_accuracy: 0.8845
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.2008 - accuracy: 0.9343 - val_loss: 0.3709 - val_accuracy: 0.8769
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.2130 - accuracy: 0.9302 - val_loss: 0.2821 - val_accuracy: 0.9038
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.1721 - accuracy: 0.9432 - val_loss: 0.4121 - val_accuracy: 0.8838
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.1875 - accuracy: 0.9417 - val_loss: 0.3302 - val_accuracy: 0.9020
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.1564 - accuracy: 0.9501 - val_loss: 0.3334 - val_accuracy: 0.8936
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.1440 - accuracy: 0.9525 - val_loss: 0.3422 - val_accuracy: 0.9077
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.1280 - accuracy: 0.9590 - val_loss: 0.4584 - val_accuracy: 0.8981
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.1942 - accuracy: 0.9384 - val_loss: 0.3773 - val_accuracy: 0.8867
#
# Best validation acc of epoch:
# 0.9076998829841614
# froz=
# 3
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 4s - loss: 1.1715 - accuracy: 0.4764 - val_loss: 0.6321 - val_accuracy: 0.7621
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.5168 - accuracy: 0.7983 - val_loss: 0.5002 - val_accuracy: 0.8134
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.4230 - accuracy: 0.8390 - val_loss: 0.3995 - val_accuracy: 0.8443
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.3712 - accuracy: 0.8607 - val_loss: 0.3859 - val_accuracy: 0.8564
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.3338 - accuracy: 0.8749 - val_loss: 0.3885 - val_accuracy: 0.8396
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.3267 - accuracy: 0.8769 - val_loss: 0.3223 - val_accuracy: 0.8771
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.2941 - accuracy: 0.8903 - val_loss: 0.2976 - val_accuracy: 0.8870
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.2771 - accuracy: 0.8954 - val_loss: 0.2943 - val_accuracy: 0.8894
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.2625 - accuracy: 0.9010 - val_loss: 0.3254 - val_accuracy: 0.8766
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.2520 - accuracy: 0.9062 - val_loss: 0.3430 - val_accuracy: 0.8586
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.2606 - accuracy: 0.8991 - val_loss: 0.2753 - val_accuracy: 0.8954
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.2404 - accuracy: 0.9094 - val_loss: 0.2908 - val_accuracy: 0.8954
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.2365 - accuracy: 0.9089 - val_loss: 0.3680 - val_accuracy: 0.8625
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.2421 - accuracy: 0.9082 - val_loss: 0.2848 - val_accuracy: 0.8954
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.2078 - accuracy: 0.9214 - val_loss: 0.3667 - val_accuracy: 0.8576
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.2200 - accuracy: 0.9156 - val_loss: 0.2823 - val_accuracy: 0.8968
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.1944 - accuracy: 0.9268 - val_loss: 0.2603 - val_accuracy: 0.9003
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.1845 - accuracy: 0.9308 - val_loss: 0.3137 - val_accuracy: 0.8798
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.1917 - accuracy: 0.9269 - val_loss: 0.2600 - val_accuracy: 0.9038
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.1688 - accuracy: 0.9360 - val_loss: 0.2805 - val_accuracy: 0.9025
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.1546 - accuracy: 0.9447 - val_loss: 0.2990 - val_accuracy: 0.8880
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.1496 - accuracy: 0.9455 - val_loss: 0.2996 - val_accuracy: 0.8926
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.1589 - accuracy: 0.9414 - val_loss: 0.3265 - val_accuracy: 0.8764
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.1514 - accuracy: 0.9450 - val_loss: 0.2618 - val_accuracy: 0.9052
#
# Epoch 25/30
# ...
#
# Epoch 23/30
# 17/17 - 7s - loss: 0.5013 - accuracy: 0.8237 - val_loss: 0.4211 - val_accuracy: 0.8450
#
# Epoch 24/30
# 17/17 - 7s - loss: 0.3854 - accuracy: 0.8601 - val_loss: 0.3701 - val_accuracy: 0.8638
#
# Epoch 25/30
# 17/17 - 7s - loss: 0.3659 - accuracy: 0.8638 - val_loss: 0.3660 - val_accuracy: 0.8633
#
# Epoch 26/30
# 17/17 - 7s - loss: 0.3436 - accuracy: 0.8748 - val_loss: 0.3393 - val_accuracy: 0.8702
#
# Epoch 27/30
# 17/17 - 7s - loss: 0.3251 - accuracy: 0.8820 - val_loss: 0.3299 - val_accuracy: 0.8736
#
# Epoch 28/30
# 17/17 - 7s - loss: 0.3080 - accuracy: 0.8889 - val_loss: 0.3727 - val_accuracy: 0.8645
#
# Epoch 29/30
# 17/17 - 7s - loss: 0.3075 - accuracy: 0.8871 - val_loss: 0.3322 - val_accuracy: 0.8746
#
# Epoch 30/30
# 17/17 - 7s - loss: 0.3005 - accuracy: 0.8887 - val_loss: 0.3336 - val_accuracy: 0.8739
#
# Best validation acc of epoch:
# 0.8746297955513
# froz=
# 12
# dense_layers=
# 1
# Epoch 1/30
# 17/17 - 6s - loss: 3.9205 - accuracy: 0.3938 - val_loss: 1.0715 - val_accuracy: 0.3218
#
# Epoch 2/30
# 17/17 - 6s - loss: 1.0725 - accuracy: 0.4325 - val_loss: 1.0310 - val_accuracy: 0.4642
#
# Epoch 3/30
# 17/17 - 6s - loss: 1.0161 - accuracy: 0.5265 - val_loss: 0.9368 - val_accuracy: 0.5958
#
# Epoch 4/30
# 17/17 - 6s - loss: 0.9237 - accuracy: 0.5877 - val_loss: 0.8447 - val_accuracy: 0.6140
#
# Epoch 5/30
# 17/17 - 6s - loss: 0.8855 - accuracy: 0.6106 - val_loss: 0.7799 - val_accuracy: 0.6394
#
# Epoch 6/30
# 17/17 - 6s - loss: 0.7995 - accuracy: 0.6348 - val_loss: 0.9236 - val_accuracy: 0.6310
#
# Epoch 7/30
# 17/17 - 6s - loss: 0.8085 - accuracy: 0.6454 - val_loss: 0.6964 - val_accuracy: 0.6656
#
# Epoch 8/30
# 17/17 - 6s - loss: 0.7041 - accuracy: 0.6964 - val_loss: 0.6648 - val_accuracy: 0.7530
#
# Epoch 9/30
# 17/17 - 6s - loss: 0.6499 - accuracy: 0.7279 - val_loss: 0.6362 - val_accuracy: 0.7611
#
# Epoch 10/30
# 17/17 - 6s - loss: 0.6130 - accuracy: 0.7421 - val_loss: 0.5535 - val_accuracy: 0.8127
#
# Epoch 11/30
# 17/17 - 6s - loss: 0.5234 - accuracy: 0.7933 - val_loss: 0.5042 - val_accuracy: 0.7991
#
# Epoch 12/30
# 17/17 - 6s - loss: 0.4962 - accuracy: 0.8134 - val_loss: 0.5458 - val_accuracy: 0.7991
#
# Epoch 13/30
# 17/17 - 6s - loss: 0.4840 - accuracy: 0.8148 - val_loss: 0.3355 - val_accuracy: 0.8806
#
# Epoch 14/30
# 17/17 - 6s - loss: 0.3914 - accuracy: 0.8483 - val_loss: 0.3372 - val_accuracy: 0.8835
#
# Epoch 15/30
# 17/17 - 6s - loss: 0.3555 - accuracy: 0.8596 - val_loss: 0.2778 - val_accuracy: 0.8986
#
# Epoch 16/30
# 17/17 - 6s - loss: 0.3695 - accuracy: 0.8569 - val_loss: 0.2790 - val_accuracy: 0.8998
#
# Epoch 17/30
# 17/17 - 6s - loss: 0.3560 - accuracy: 0.8716 - val_loss: 0.5461 - val_accuracy: 0.8082
#
# Epoch 18/30
# 17/17 - 6s - loss: 0.3621 - accuracy: 0.8752 - val_loss: 0.2876 - val_accuracy: 0.9040
#
# Epoch 19/30
# 17/17 - 6s - loss: 0.2979 - accuracy: 0.9051 - val_loss: 0.2709 - val_accuracy: 0.9030
#
# Epoch 20/30
# 17/17 - 6s - loss: 0.2974 - accuracy: 0.9012 - val_loss: 0.2558 - val_accuracy: 0.9097
#
# Epoch 21/30
# 17/17 - 6s - loss: 0.2806 - accuracy: 0.9068 - val_loss: 0.2578 - val_accuracy: 0.9089
#
# Epoch 22/30
# 17/17 - 6s - loss: 0.2574 - accuracy: 0.9130 - val_loss: 0.2401 - val_accuracy: 0.9176
#
# Epoch 23/30
# 17/17 - 6s - loss: 0.2351 - accuracy: 0.9212 - val_loss: 0.2585 - val_accuracy: 0.9121
#
# Epoch 24/30
# 17/17 - 6s - loss: 0.2544 - accuracy: 0.9136 - val_loss: 0.2366 - val_accuracy: 0.9208
#
# Epoch 25/30
# 17/17 - 6s - loss: 0.2760 - accuracy: 0.9081 - val_loss: 0.2444 - val_accuracy: 0.9171
#
# Epoch 26/30
# 17/17 - 6s - loss: 0.2309 - accuracy: 0.9231 - val_loss: 0.2348 - val_accuracy: 0.9205
#
# Epoch 27/30
# 17/17 - 6s - loss: 0.2183 - accuracy: 0.9252 - val_loss: 0.2353 - val_accuracy: 0.9257
#
# Epoch 28/30
# 17/17 - 6s - loss: 0.2267 - accuracy: 0.9235 - val_loss: 0.2550 - val_accuracy: 0.9223
#
# Epoch 29/30
# 17/17 - 6s - loss: 0.2127 - accuracy: 0.9260 - val_loss: 0.2505 - val_accuracy: 0.9225
#
# Epoch 30/30
# 17/17 - 6s - loss: 0.2186 - accuracy: 0.9261 - val_loss: 0.2886 - val_accuracy: 0.9033
#
# Best validation acc of epoch:
# 0.9257156848907471
# froz=
# 1
# dense_layers=
# 2
# Epoch 1/30
# 17/17 - 4s - loss: 1.0776 - accuracy: 0.4534 - val_loss: 0.9234 - val_accuracy: 0.6333
#
# Epoch 2/30
# 17/17 - 4s - loss: 0.9122 - accuracy: 0.5814 - val_loss: 0.8030 - val_accuracy: 0.6444
#
# Epoch 3/30
# 17/17 - 4s - loss: 0.8311 - accuracy: 0.6312 - val_loss: 0.7305 - val_accuracy: 0.6755
#
# Epoch 4/30
# 17/17 - 4s - loss: 0.7695 - accuracy: 0.6647 - val_loss: 0.6715 - val_accuracy: 0.7354
#
# Epoch 5/30
# 17/17 - 4s - loss: 0.7195 - accuracy: 0.7070 - val_loss: 0.6111 - val_accuracy: 0.7695
#
# Epoch 6/30
# 17/17 - 4s - loss: 0.6721 - accuracy: 0.7360 - val_loss: 0.5674 - val_accuracy: 0.7895
#
# Epoch 7/30
# 17/17 - 4s - loss: 0.6357 - accuracy: 0.7583 - val_loss: 0.5365 - val_accuracy: 0.8006
#
# Epoch 8/30
# 17/17 - 4s - loss: 0.6056 - accuracy: 0.7708 - val_loss: 0.5148 - val_accuracy: 0.8038
#
# Epoch 9/30
# 17/17 - 4s - loss: 0.5854 - accuracy: 0.7810 - val_loss: 0.4963 - val_accuracy: 0.8147
#
# Epoch 10/30
# 17/17 - 4s - loss: 0.5635 - accuracy: 0.7860 - val_loss: 0.4845 - val_accuracy: 0.8181
#
# Epoch 11/30
# 17/17 - 4s - loss: 0.5588 - accuracy: 0.7907 - val_loss: 0.4737 - val_accuracy: 0.8203
#
# Epoch 12/30
# 17/17 - 4s - loss: 0.5384 - accuracy: 0.7998 - val_loss: 0.4588 - val_accuracy: 0.8268
#
# Epoch 13/30
# 17/17 - 4s - loss: 0.5295 - accuracy: 0.8002 - val_loss: 0.4566 - val_accuracy: 0.8265
#
# Epoch 14/30
# 17/17 - 4s - loss: 0.5109 - accuracy: 0.8082 - val_loss: 0.4487 - val_accuracy: 0.8295
#
# Epoch 15/30
# 17/17 - 4s - loss: 0.5094 - accuracy: 0.8117 - val_loss: 0.4404 - val_accuracy: 0.8292
#
# Epoch 16/30
# 17/17 - 4s - loss: 0.4981 - accuracy: 0.8111 - val_loss: 0.4355 - val_accuracy: 0.8322
#
# Epoch 17/30
# 17/17 - 4s - loss: 0.4917 - accuracy: 0.8136 - val_loss: 0.4299 - val_accuracy: 0.8354
#
# Epoch 18/30
# 17/17 - 4s - loss: 0.4848 - accuracy: 0.8198 - val_loss: 0.4277 - val_accuracy: 0.8359
#
# Epoch 19/30
# 17/17 - 4s - loss: 0.4776 - accuracy: 0.8227 - val_loss: 0.4217 - val_accuracy: 0.8384
#
# Epoch 20/30
# 17/17 - 4s - loss: 0.4748 - accuracy: 0.8237 - val_loss: 0.4160 - val_accuracy: 0.8376
#
# Epoch 21/30
# 17/17 - 4s - loss: 0.4644 - accuracy: 0.8239 - val_loss: 0.4151 - val_accuracy: 0.8418
#
# Epoch 22/30
# 17/17 - 4s - loss: 0.4656 - accuracy: 0.8281 - val_loss: 0.4091 - val_accuracy: 0.8440
#
# Epoch 23/30
# 17/17 - 4s - loss: 0.4579 - accuracy: 0.8296 - val_loss: 0.4094 - val_accuracy: 0.8438
#
# Epoch 24/30
# 17/17 - 4s - loss: 0.4502 - accuracy: 0.8314 - val_loss: 0.4036 - val_accuracy: 0.8467
#
# Epoch 25/30
# 17/17 - 4s - loss: 0.4490 - accuracy: 0.8312 - val_loss: 0.4046 - val_accuracy: 0.8453
#
# Epoch 26/30
# 17/17 - 4s - loss: 0.4482 - accuracy: 0.8337 - val_loss: 0.3982 - val_accuracy: 0.8428
#
# Epoch 27/30
# 17/17 - 4s - loss: 0.4395 - accuracy: 0.8351 - val_loss: 0.4103 - val_accuracy: 0.8487
#
# Epoch 28/30
# 17/17 - 4s - loss: 0.4372 - accuracy: 0.8404 - val_loss: 0.3945 - val_accuracy: 0.8502
#
# Epoch 29/30
# 17/17 - 4s - loss: 0.4358 - accuracy: 0.8358 - val_loss: 0.3916 - val_accuracy: 0.8504
#
# Epoch 30/30
# 17/17 - 4s - loss: 0.4302 - accuracy: 0.8377 - val_loss: 0.3936 - val_accuracy: 0.8522
#
# Best validation acc of epoch:
# 0.852171778678894
# froz=
# 10
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 6s - loss: 2.4393 - accuracy: 0.3986 - val_loss: 1.0623 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 5s - loss: 1.0316 - accuracy: 0.4737 - val_loss: 0.9781 - val_accuracy: 0.5405
#
# Epoch 3/30
# 17/17 - 5s - loss: 0.9718 - accuracy: 0.5463 - val_loss: 0.8692 - val_accuracy: 0.5995
#
# Epoch 4/30
# 17/17 - 5s - loss: 0.8475 - accuracy: 0.6105 - val_loss: 0.7986 - val_accuracy: 0.6286
#
# Epoch 5/30
# 17/17 - 5s - loss: 0.7516 - accuracy: 0.6420 - val_loss: 0.7013 - val_accuracy: 0.6579
#
# Epoch 6/30
# 17/17 - 5s - loss: 0.7126 - accuracy: 0.6724 - val_loss: 0.6424 - val_accuracy: 0.7295
#
# Epoch 7/30
# 17/17 - 5s - loss: 0.6179 - accuracy: 0.7309 - val_loss: 0.5720 - val_accuracy: 0.7707
#
# Epoch 8/30
# 17/17 - 5s - loss: 0.5120 - accuracy: 0.8032 - val_loss: 0.4493 - val_accuracy: 0.8329
#
# Epoch 9/30
# 17/17 - 5s - loss: 0.3990 - accuracy: 0.8507 - val_loss: 0.6163 - val_accuracy: 0.7616
#
# Epoch 10/30
# 17/17 - 5s - loss: 0.5140 - accuracy: 0.8070 - val_loss: 0.3988 - val_accuracy: 0.8527
#
# Epoch 11/30
# 17/17 - 5s - loss: 0.3684 - accuracy: 0.8688 - val_loss: 0.3429 - val_accuracy: 0.8727
#
# Epoch 12/30
# 17/17 - 5s - loss: 0.3207 - accuracy: 0.8829 - val_loss: 0.3083 - val_accuracy: 0.8857
#
# Epoch 13/30
# 17/17 - 5s - loss: 0.2842 - accuracy: 0.8957 - val_loss: 0.2832 - val_accuracy: 0.8954
#
# Epoch 14/30
# 17/17 - 5s - loss: 0.2918 - accuracy: 0.8952 - val_loss: 0.3324 - val_accuracy: 0.8731
#
# Epoch 15/30
# 17/17 - 5s - loss: 0.2954 - accuracy: 0.8921 - val_loss: 0.3067 - val_accuracy: 0.8944
#
# Epoch 16/30
# 17/17 - 5s - loss: 0.2555 - accuracy: 0.9081 - val_loss: 0.2637 - val_accuracy: 0.8988
#
# Epoch 17/30
# 17/17 - 5s - loss: 0.2310 - accuracy: 0.9153 - val_loss: 0.2527 - val_accuracy: 0.9065
#
# Epoch 18/30
# 17/17 - 5s - loss: 0.2157 - accuracy: 0.9196 - val_loss: 0.2490 - val_accuracy: 0.9077
#
# Epoch 19/30
# 17/17 - 5s - loss: 0.2035 - accuracy: 0.9242 - val_loss: 0.2601 - val_accuracy: 0.9050
#
# Epoch 20/30
# 17/17 - 5s - loss: 0.1967 - accuracy: 0.9276 - val_loss: 0.2336 - val_accuracy: 0.9099
#
# Epoch 21/30
# 17/17 - 5s - loss: 0.1832 - accuracy: 0.9324 - val_loss: 0.2440 - val_accuracy: 0.9144
#
# Epoch 22/30
# 17/17 - 5s - loss: 0.1725 - accuracy: 0.9358 - val_loss: 0.2933 - val_accuracy: 0.8904
#
# Epoch 23/30
# 17/17 - 5s - loss: 0.1749 - accuracy: 0.9327 - val_loss: 0.2198 - val_accuracy: 0.9223
#
# Epoch 24/30
# 17/17 - 5s - loss: 0.1448 - accuracy: 0.9459 - val_loss: 0.2336 - val_accuracy: 0.9200
#
# Epoch 25/30
# 17/17 - 5s - loss: 0.1419 - accuracy: 0.9457 - val_loss: 0.2309 - val_accuracy: 0.9161
#
# Epoch 26/30
# 17/17 - 5s - loss: 0.1395 - accuracy: 0.9472 - val_loss: 0.3283 - val_accuracy: 0.8924
#
# Epoch 27/30
# 17/17 - 5s - loss: 0.1591 - accuracy: 0.9402 - val_loss: 0.2529 - val_accuracy: 0.9112
#
# Epoch 28/30
# 17/17 - 5s - loss: 0.1361 - accuracy: 0.9487 - val_loss: 0.2473 - val_accuracy: 0.9210
#
# Epoch 29/30
# 17/17 - 5s - loss: 0.1238 - accuracy: 0.9542 - val_loss: 0.2513 - val_accuracy: 0.9205
#
# Epoch 30/30
# 17/17 - 5s - loss: 0.1028 - accuracy: 0.9630 - val_loss: 0.2487 - val_accuracy: 0.9228
#
# Best validation acc of epoch:
# 0.922754168510437
# froz=
# 17
# dense_layers=
# 1
# Epoch 1/30
# 17/17 - 8s - loss: 20.5912 - accuracy: 0.3968 - val_loss: 1.0545 - val_accuracy: 0.4640
#
# Epoch 2/30
# 17/17 - 8s - loss: 1.0564 - accuracy: 0.4557 - val_loss: 1.0427 - val_accuracy: 0.4640
#
# Epoch 3/30
# 17/17 - 8s - loss: 1.0458 - accuracy: 0.4611 - val_loss: 1.0458 - val_accuracy: 0.5731
#
# Epoch 4/30
# 17/17 - 8s - loss: 1.0366 - accuracy: 0.4826 - val_loss: 1.0435 - val_accuracy: 0.4640
#
# Epoch 5/30
# 17/17 - 8s - loss: 1.0214 - accuracy: 0.5136 - val_loss: 1.0178 - val_accuracy: 0.4699
#
# Epoch 6/30
# 17/17 - 8s - loss: 0.9950 - accuracy: 0.5315 - val_loss: 0.9326 - val_accuracy: 0.5943
#
# Epoch 7/30
# 17/17 - 8s - loss: 0.9439 - accuracy: 0.5765 - val_loss: 0.8837 - val_accuracy: 0.6019
#
# Epoch 8/30
# 17/17 - 8s - loss: 0.9073 - accuracy: 0.5916 - val_loss: 0.9459 - val_accuracy: 0.5908
#
# Epoch 9/30
# 17/17 - 8s - loss: 0.8811 - accuracy: 0.6010 - val_loss: 0.8096 - val_accuracy: 0.6269
#
# Epoch 10/30
# 17/17 - 8s - loss: 0.8241 - accuracy: 0.6273 - val_loss: 0.8016 - val_accuracy: 0.6343
#
# Epoch 11/30
# 17/17 - 8s - loss: 0.7513 - accuracy: 0.6654 - val_loss: 0.7473 - val_accuracy: 0.6750
#
# Epoch 12/30
# 17/17 - 8s - loss: 0.7539 - accuracy: 0.6736 - val_loss: 0.6583 - val_accuracy: 0.7137
#
# Epoch 13/30
# 17/17 - 8s - loss: 0.6275 - accuracy: 0.7462 - val_loss: 0.6321 - val_accuracy: 0.7384
#
# Epoch 14/30
# 17/17 - 8s - loss: 0.5545 - accuracy: 0.7850 - val_loss: 0.5445 - val_accuracy: 0.7969
#
# Epoch 15/30
# 17/17 - 8s - loss: 0.4881 - accuracy: 0.8161 - val_loss: 0.4703 - val_accuracy: 0.8164
#
# Epoch 16/30
# 17/17 - 8s - loss: 0.4173 - accuracy: 0.8480 - val_loss: 0.5188 - val_accuracy: 0.8001
#
# Epoch 17/30
# 17/17 - 8s - loss: 0.3977 - accuracy: 0.8551 - val_loss: 0.4106 - val_accuracy: 0.8443
#
# Epoch 18/30
# 17/17 - 8s - loss: 0.3892 - accuracy: 0.8598 - val_loss: 0.3680 - val_accuracy: 0.8657
#
# Epoch 19/30
# 17/17 - 8s - loss: 0.3475 - accuracy: 0.8765 - val_loss: 0.3555 - val_accuracy: 0.8699
#
# Epoch 20/30
# 17/17 - 8s - loss: 0.3300 - accuracy: 0.8806 - val_loss: 0.3395 - val_accuracy: 0.8751
#
# Epoch 21/30
# 17/17 - 8s - loss: 0.3172 - accuracy: 0.8864 - val_loss: 0.3847 - val_accuracy: 0.8643
#
# Epoch 22/30
# 17/17 - 8s - loss: 0.3099 - accuracy: 0.8893 - val_loss: 0.3263 - val_accuracy: 0.8815
#
# Epoch 23/30
# 17/17 - 8s - loss: 0.2880 - accuracy: 0.8972 - val_loss: 0.3088 - val_accuracy: 0.8857
#
# Epoch 24/30
# 17/17 - 8s - loss: 0.2780 - accuracy: 0.9007 - val_loss: 0.3089 - val_accuracy: 0.8885
#
# Epoch 25/30
# 17/17 - 8s - loss: 0.2727 - accuracy: 0.9029 - val_loss: 0.3058 - val_accuracy: 0.8889
#
# Epoch 26/30
# 17/17 - 8s - loss: 0.2544 - accuracy: 0.9093 - val_loss: 0.2996 - val_accuracy: 0.8899
#
# Epoch 27/30
# 17/17 - 8s - loss: 0.2635 - accuracy: 0.9053 - val_loss: 0.3059 - val_accuracy: 0.8862
#
# Epoch 28/30
# 17/17 - 8s - loss: 0.2878 - accuracy: 0.8931 - val_loss: 0.3598 - val_accuracy: 0.8650
#
# Epoch 29/30
# 17/17 - 8s - loss: 0.2816 - accuracy: 0.8970 - val_loss: 0.3310 - val_accuracy: 0.8783
#
# Epoch 30/30
# 17/17 - 8s - loss: 0.2627 - accuracy: 0.9038 - val_loss: 0.3149 - val_accuracy: 0.8855
#
# Best validation acc of epoch:
# 0.8899309039115906
# froz=
# 15
# dense_layers=
# 0
# Epoch 1/30
# 17/17 - 7s - loss: 10.1571 - accuracy: 0.4192 - val_loss: 1.0235 - val_accuracy: 0.4726
#
# Epoch 2/30
# 17/17 - 7s - loss: 1.0531 - accuracy: 0.4493 - val_loss: 1.0387 - val_accuracy: 0.4699
#
# Epoch 3/30
# 17/17 - 7s - loss: 1.0263 - accuracy: 0.4871 - val_loss: 1.0823 - val_accuracy: 0.4642
#
# Epoch 4/30
# 17/17 - 7s - loss: 1.0515 - accuracy: 0.4569 - val_loss: 0.9862 - val_accuracy: 0.5439
#
# Epoch 5/30
# 17/17 - 7s - loss: 0.9568 - accuracy: 0.5585 - val_loss: 0.9512 - val_accuracy: 0.5703
#
# Epoch 6/30
# 17/17 - 7s - loss: 0.9145 - accuracy: 0.5850 - val_loss: 0.9227 - val_accuracy: 0.5866
#
# Epoch 7/30
# 17/17 - 7s - loss: 0.9015 - accuracy: 0.5982 - val_loss: 0.8684 - val_accuracy: 0.6172
#
# Epoch 8/30
# 17/17 - 7s - loss: 0.8616 - accuracy: 0.6120 - val_loss: 0.8122 - val_accuracy: 0.6365
#
# Epoch 9/30
# 17/17 - 7s - loss: 0.7693 - accuracy: 0.6613 - val_loss: 0.8016 - val_accuracy: 0.6486
#
# Epoch 10/30
# 17/17 - 7s - loss: 0.7381 - accuracy: 0.6841 - val_loss: 0.6814 - val_accuracy: 0.7187
#
# Epoch 11/30
# 17/17 - 7s - loss: 0.6515 - accuracy: 0.7300 - val_loss: 0.5462 - val_accuracy: 0.7850
#
# Epoch 12/30
# 17/17 - 7s - loss: 0.4886 - accuracy: 0.8154 - val_loss: 0.5835 - val_accuracy: 0.7577
#
# Epoch 13/30
# 17/17 - 7s - loss: 0.4602 - accuracy: 0.8268 - val_loss: 0.4173 - val_accuracy: 0.8448
#
# Epoch 14/30
# 17/17 - 7s - loss: 0.3625 - accuracy: 0.8669 - val_loss: 0.3464 - val_accuracy: 0.8764
#
# Epoch 15/30
# 17/17 - 7s - loss: 0.3465 - accuracy: 0.8722 - val_loss: 0.4043 - val_accuracy: 0.8445
#
# Epoch 16/30
# 17/17 - 7s - loss: 0.3225 - accuracy: 0.8810 - val_loss: 0.3991 - val_accuracy: 0.8588
#
# Epoch 17/30
# 17/17 - 7s - loss: 0.3207 - accuracy: 0.8832 - val_loss: 0.3298 - val_accuracy: 0.8813
#
# Epoch 18/30
# 17/17 - 7s - loss: 0.2822 - accuracy: 0.8970 - val_loss: 0.3557 - val_accuracy: 0.8731
#
# Epoch 19/30
# 17/17 - 7s - loss: 0.2771 - accuracy: 0.9017 - val_loss: 0.2932 - val_accuracy: 0.8924
#
# Epoch 20/30
# 17/17 - 7s - loss: 0.2466 - accuracy: 0.9129 - val_loss: 0.3171 - val_accuracy: 0.8882
#
# Epoch 21/30
# 17/17 - 7s - loss: 0.2509 - accuracy: 0.9104 - val_loss: 0.2953 - val_accuracy: 0.8988
#
# Epoch 22/30
# 17/17 - 7s - loss: 0.2558 - accuracy: 0.9056 - val_loss: 0.2960 - val_accuracy: 0.8919
#
# Epoch 23/30
# 17/17 - 7s - loss: 0.2332 - accuracy: 0.9152 - val_loss: 0.3304 - val_accuracy: 0.8810
#
# Epoch 24/30
# 17/17 - 7s - loss: 0.2241 - accuracy: 0.9194 - val_loss: 0.2505 - val_accuracy: 0.9131
#
# Epoch 25/30
# 17/17 - 7s - loss: 0.2041 - accuracy: 0.9274 - val_loss: 0.2572 - val_accuracy: 0.9057
#
# Epoch 26/30
# 17/17 - 7s - loss: 0.1906 - accuracy: 0.9306 - val_loss: 0.2980 - val_accuracy: 0.8986
#
# Epoch 27/30
# 17/17 - 7s - loss: 0.1956 - accuracy: 0.9284 - val_loss: 0.2717 - val_accuracy: 0.9025
#
# Epoch 28/30
#  12%|█▏        | 35/300 [1:42:34<13:49:18, 187.77s/it, best loss: -0.9281836152076721]
