# %%
# !pip install --upgrade pactools
# !pip install hyperas
# !pip install hyperopt
# !pip install -U -q PyDrive
# !pip install skimage
# Out:
# Requirement already up-to-date: pactools in /usr/local/lib/python3.6/dist-packages (0.3)
# Requirement already satisfied: hyperas in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.3)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.0.7)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.6/dist-packages (from hyperas) (1.0.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from hyperas) (5.6.1)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (from hyperas) (0.1.2)
# Requirement already satisfied: keras in /usr/local/lib/python3.6/dist-packages (from hyperas) (2.4.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (4.6.3)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (4.3.3)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (0.2.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat->hyperas) (2.6.0)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.2.0)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.7.5)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (4.10.1)
# Requirement already satisfied: notebook in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (5.3.1)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.6/dist-packages (from jupyter->hyperas) (7.5.1)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (3.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.4.4)
# Requirement already satisfied: jinja2>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.11.2)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (2.1.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->hyperas) (0.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (3.11.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (1.4.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (2.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (1.15.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt->hyperas) (4.41.1)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras->hyperas) (2.10.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from traitlets>=4.1->nbformat->hyperas) (4.4.2)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (1.0.18)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (5.3.5)
# Requirement already satisfied: ipython in /usr/local/lib/python3.6/dist-packages (from jupyter-console->jupyter->hyperas) (5.5.0)
# Requirement already satisfied: pyzmq>=17.1 in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->hyperas) (19.0.2)
# Requirement already satisfied: qtpy in /usr/local/lib/python3.6/dist-packages (from qtconsole->jupyter->hyperas) (1.9.0)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel->jupyter->hyperas) (5.1.1)
# Requirement already satisfied: Send2Trash in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (1.5.0)
# Requirement already satisfied: terminado>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from notebook->jupyter->hyperas) (0.8.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets->jupyter->hyperas) (3.5.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->hyperas) (20.4)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->hyperas) (0.5.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2>=2.4->nbconvert->hyperas) (1.1.1)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.0->jupyter-console->jupyter->hyperas) (0.2.5)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->jupyter-console->jupyter->hyperas) (2.8.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.7.5)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (0.8.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (49.2.0)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython->jupyter-console->jupyter->hyperas) (4.8.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /usr/local/lib/python3.6/dist-packages (from terminado>=0.8.1->notebook->jupyter->hyperas) (0.6.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->bleach->nbconvert->hyperas) (2.4.7)
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.6/dist-packages (from hyperopt) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.6/dist-packages (from hyperopt) (2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.18.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from hyperopt) (4.41.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from hyperopt) (1.15.0)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx->hyperopt) (4.4.2)
# Collecting skimage
#   Using cached https://files.pythonhosted.org/packages/3b/ee/edbfa69ba7b7d9726e634bfbeefd04b5a1764e9e74867ec916113eeaf4a1/skimage-0.0.tar.gz
# ERROR: Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.

# %%
# Install the PyDrive wrapper & import libraries.
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# Copy/download the file
fid = drive.ListFile({'q':"title='hyperas_xception.ipynb'"}).GetList()[0]['id']
f = drive.CreateFile({'id': fid})
f.GetContentFile('hyperas_xception.ipynb')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from hyperopt import Trials, STATUS_OK, tpe
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib.ticker import MaxNLocator

#TESNORFOW
import tensorflow as tf
from tensorflow import keras
from keras import datasets, layers, models

#KERAS LIBRARIES
from keras.preprocessing.text import Tokenizer
from keras.models import Sequential,Model
from keras.layers import Dense, Dropout , Flatten,BatchNormalization,Conv2D,MaxPooling2D, Activation,LSTM,Embedding,Input,GlobalAveragePooling2D
from keras.regularizers import l1, l2, l1_l2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras import backend 
from keras.utils import np_utils
from keras.utils import to_categorical

#CROSS VALIDATION
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from pactools.grid_search import GridSearchCVProgressBar

#WRAPPERS NEEDED FOR GRIDSEARCH
from keras.wrappers.scikit_learn import KerasClassifier
from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import train_test_split

from hyperas import optim
from hyperas.distributions import choice, uniform
import skimage
import skimage.transform
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
def data():
  train1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train.npy',allow_pickle=True)
  train_labels1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train_labels.npy',allow_pickle=True)
  
  train4=np.empty([20260, 72,72,3], dtype=int)
  
  for i in range(len(train1)):
    train4[i] = skimage.transform.resize(train1[i], (72, 72))
  
  train2,test1, train_labels2,test_labels1 = train_test_split(train4, train_labels1, test_size=0.2, random_state=42)
  
  x_train=train2/225.0
  y_train = pd.get_dummies(train_labels2)

  x_test=test1/225.0
  y_test = pd.get_dummies(test_labels1)
  return x_train,y_train,x_test,y_test

# %%
IMG_SHAPE2=(72,72,3) 
xception=keras.applications.xception.Xception(input_shape=IMG_SHAPE2,
                                               include_top=False,
                                               weights='imagenet')

# %%
def create_model_dense_xception(x_train,y_train,x_test,y_test): 
  IMG_SHAPE2=(72,72,3) 
  xception=keras.applications.xception.Xception(input_shape=IMG_SHAPE2,
                                               include_top=False,
                                               weights='imagenet')
  tempex=xception
  froz={{choice([3,6,10,15,20,25,30,40,60])}}
  for layer in tempex.layers[:(-1)*froz]:
    layer.trainable = False
  
  model = tf.keras.Sequential()
  model.add(tempex)
  if ({{choice([0,1])}}):
    model.add(keras.layers.Flatten())
  else:
    model.add(keras.layers.GlobalAveragePooling2D())
  dense_layer_size={{choice([0,1,2,3])}}
  if (dense_layer_size==3):
    model.add(keras.layers.Dense(128, activation='relu'))
    model.add(keras.layers.Dropout(0.5))
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  elif (dense_layer_size==2):
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  elif (dense_layer_size==1):
    model.add(keras.layers.Dense(32, activation='relu'))
    model.add(keras.layers.Dropout({{choice([0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65])}}))
  else:
    layers=[]
    for i in range(len(layers)):
          model.add(keras.layers.Dense(layers[i], activation='relu'))
          model.add(keras.layers.Dropout(0.1))
  model.add(keras.layers.Dense(3,activation="softmax"))
  print('froz=',froz,'dense_layers=',dense_layer_size) 
  model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy"])
  result = model.fit(x_train, y_train,
              batch_size=1000,
              epochs=5,
              verbose=2,
              validation_data=(x_test, y_test))
  validation_acc = np.amax(result.history['val_accuracy']) 
  print('Best validation acc of epoch:', validation_acc)
  return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
best_run, best_model = optim.minimize(model=create_model_dense_xception,
                                          data=data,
                                          algo=tpe.suggest,
                                          max_evals=300,
                                          notebook_name='hyperas_xception',
                                          trials=Trials())
X_train, Y_train, X_test, Y_test = data()
print("Evalutation of best performing model:")
print(best_model.evaluate(X_test, Y_test))
print("Best performing model chosen hyper-parameters:")
print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     from pydrive.auth import GoogleAuth
# except:
#     pass
#
# try:
#     from pydrive.drive import GoogleDrive
# except:
#     pass
#
# try:
#     from google.colab import auth
# except:
#     pass
#
# try:
#     from oauth2client.client import GoogleCredentials
# except:
#     pass
#
# try:
#     from google.colab import drive
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     from matplotlib.ticker import MaxNLocator
# except:
#     pass
#
# try:
#     import tensorflow as tf
# except:
#     pass
#
# try:
#     from tensorflow import keras
# except:
#     pass
#
# try:
#     from keras import datasets, layers, models
# except:
#     pass
#
# try:
#     from keras.preprocessing.text import Tokenizer
# except:
#     pass
#
# try:
#     from keras.models import Sequential, Model
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Dropout, Flatten, BatchNormalization, Conv2D, MaxPooling2D, Activation, LSTM, Embedding, Input, GlobalAveragePooling2D
# except:
#     pass
#
# try:
#     from keras.regularizers import l1, l2, l1_l2
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping, ModelCheckpoint
# except:
#     pass
#
# try:
#     from keras import backend
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from keras.utils import to_categorical
# except:
#     pass
#
# try:
#     from sklearn.model_selection import StratifiedKFold
# except:
#     pass
#
# try:
#     from sklearn.model_selection import GridSearchCV
# except:
#     pass
#
# try:
#     from pactools.grid_search import GridSearchCVProgressBar
# except:
#     pass
#
# try:
#     from keras.wrappers.scikit_learn import KerasClassifier
# except:
#     pass
#
# try:
#     from keras.wrappers.scikit_learn import KerasRegressor
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# try:
#     import skimage
# except:
#     pass
#
# try:
#     import skimage.transform
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'froz': hp.choice('froz', [3,6,10,15,20,25,30,40,60]),
#         'if': hp.choice('if', [0,1]),
#         'dense_layer_size': hp.choice('dense_layer_size', [0,1,2,3]),
#         'Dropout': hp.choice('Dropout', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_1': hp.choice('Dropout_1', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_2': hp.choice('Dropout_2', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_3': hp.choice('Dropout_3', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#         'Dropout_4': hp.choice('Dropout_4', [0.0,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65]),
#     }
#
# >>> Data
#   1:
#   2: train1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train.npy',allow_pickle=True)
#   3: train_labels1 = np.load('/content/drive/My Drive/NumpyArrayCovidx/train_labels.npy',allow_pickle=True)
#   4:
#   5: train4=np.empty([20260, 72,72,3], dtype=int)
#   6:
#   7: for i in range(len(train1)):
#   8:   train4[i] = skimage.transform.resize(train1[i], (72, 72))
#   9:
#  10: train2,test1, train_labels2,test_labels1 = train_test_split(train4, train_labels1, test_size=0.2, random_state=42)
#  11:
#  12: x_train=train2/225.0
#  13: y_train = pd.get_dummies(train_labels2)
#  14:
#  15: x_test=test1/225.0
#  16: y_test = pd.get_dummies(test_labels1)
#  17:
#  18:
#  19:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:   IMG_SHAPE2=(72,72,3)
#    4:   xception=keras.applications.xception.Xception(input_shape=IMG_SHAPE2,
#    5:                                                include_top=False,
#    6:                                                weights='imagenet')
#    7:   tempex=xception
#    8:   froz=space['froz']
#    9:   for layer in tempex.layers[:(-1)*froz]:
#   10:     layer.trainable = False
#   11:
#   12:   model = tf.keras.Sequential()
#   13:   model.add(tempex)
#   14:   if (space['if']):
#   15:     model.add(keras.layers.Flatten())
#   16:   else:
#   17:     model.add(keras.layers.GlobalAveragePooling2D())
#   18:   dense_layer_size=space['dense_layer_size']
#   19:   if (dense_layer_size==3):
#   20:     model.add(keras.layers.Dense(128, activation='relu'))
#   21:     model.add(keras.layers.Dropout(0.5))
#   22:     model.add(keras.layers.Dense(64, activation='relu'))
#   23:     model.add(keras.layers.Dropout(space['Dropout']))
#   24:     model.add(keras.layers.Dense(32, activation='relu'))
#   25:     model.add(keras.layers.Dropout(space['Dropout_1']))
#   26:   elif (dense_layer_size==2):
#   27:     model.add(keras.layers.Dense(64, activation='relu'))
#   28:     model.add(keras.layers.Dropout(space['Dropout_2']))
#   29:     model.add(keras.layers.Dense(32, activation='relu'))
#   30:     model.add(keras.layers.Dropout(space['Dropout_3']))
#   31:   elif (dense_layer_size==1):
#   32:     model.add(keras.layers.Dense(32, activation='relu'))
#   33:     model.add(keras.layers.Dropout(space['Dropout_4']))
#   34:   else:
#   35:     layers=[]
#   36:     for i in range(len(layers)):
#   37:           model.add(keras.layers.Dense(layers[i], activation='relu'))
#   38:           model.add(keras.layers.Dropout(0.1))
#   39:   model.add(keras.layers.Dense(3,activation="softmax"))
#   40:   print('froz=',froz,'dense_layers=',dense_layer_size)
#   41:   model.compile(loss='categorical_crossentropy', optimizer="adam", metrics=["accuracy"])
#   42:   result = model.fit(x_train, y_train,
#   43:               batch_size=1000,
#   44:               epochs=5,
#   45:               verbose=2,
#   46:               validation_data=(x_test, y_test))
#   47:   validation_acc = np.amax(result.history['val_accuracy'])
#   48:   print('Best validation acc of epoch:', validation_acc)
#   49:   return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   50:
# froz=
# 6
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 7s - loss: 0.4982 - accuracy: 0.8036 - val_loss: 0.5311 - val_accuracy: 0.8164
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.2632 - accuracy: 0.9013 - val_loss: 0.5175 - val_accuracy: 0.8147
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.1825 - accuracy: 0.9319 - val_loss: 0.3841 - val_accuracy: 0.8583
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1176 - accuracy: 0.9594 - val_loss: 0.4770 - val_accuracy: 0.8598
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.0689 - accuracy: 0.9801 - val_loss: 0.4242 - val_accuracy: 0.8741
#
# Best validation acc of epoch:
# 0.874136209487915
# froz=
# 30
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 8s - loss: 1.0744 - accuracy: 0.5231 - val_loss: 0.9266 - val_accuracy: 0.6377
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.6071 - accuracy: 0.8094 - val_loss: 0.8331 - val_accuracy: 0.7621
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.2950 - accuracy: 0.8958 - val_loss: 0.6492 - val_accuracy: 0.8285
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.2056 - accuracy: 0.9249 - val_loss: 0.5222 - val_accuracy: 0.8586
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.1557 - accuracy: 0.9440 - val_loss: 0.4232 - val_accuracy: 0.8707
#
# Best validation acc of epoch:
# 0.8706811666488647
# froz=
# 10
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 7s - loss: 0.6991 - accuracy: 0.7271 - val_loss: 1.6434 - val_accuracy: 0.7744
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3917 - accuracy: 0.8616 - val_loss: 0.8617 - val_accuracy: 0.8369
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.3091 - accuracy: 0.8933 - val_loss: 0.5920 - val_accuracy: 0.8566
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2596 - accuracy: 0.9098 - val_loss: 0.4869 - val_accuracy: 0.8606
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2054 - accuracy: 0.9271 - val_loss: 0.5094 - val_accuracy: 0.8657
#
# Best validation acc of epoch:
# 0.8657453060150146
# froz=
# 25
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 8s - loss: 1.0390 - accuracy: 0.4777 - val_loss: 2.6968 - val_accuracy: 0.6234
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.5738 - accuracy: 0.7747 - val_loss: 1.3926 - val_accuracy: 0.7734
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.3035 - accuracy: 0.8976 - val_loss: 0.9860 - val_accuracy: 0.8231
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.2180 - accuracy: 0.9213 - val_loss: 0.8091 - val_accuracy: 0.8418
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.1574 - accuracy: 0.9458 - val_loss: 1.1185 - val_accuracy: 0.8191
#
# Best validation acc of epoch:
# 0.8418065309524536
# froz=
# 30
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 8s - loss: 1.1114 - accuracy: 0.4413 - val_loss: 1.0880 - val_accuracy: 0.4341
#
# Epoch 2/5
# 17/17 - 8s - loss: 1.0624 - accuracy: 0.4814 - val_loss: 1.0413 - val_accuracy: 0.5022
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.9067 - accuracy: 0.6115 - val_loss: 0.8027 - val_accuracy: 0.6293
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.6642 - accuracy: 0.7652 - val_loss: 0.5918 - val_accuracy: 0.7502
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.3762 - accuracy: 0.8777 - val_loss: 0.5424 - val_accuracy: 0.8657
#
# Best validation acc of epoch:
# 0.8657453060150146
# froz=
# 30
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 8s - loss: 0.7285 - accuracy: 0.7692 - val_loss: 0.7145 - val_accuracy: 0.7137
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.2767 - accuracy: 0.9000 - val_loss: 0.6779 - val_accuracy: 0.8119
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.1822 - accuracy: 0.9318 - val_loss: 0.5402 - val_accuracy: 0.8672
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1257 - accuracy: 0.9520 - val_loss: 0.6990 - val_accuracy: 0.8421
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.0781 - accuracy: 0.9731 - val_loss: 0.6514 - val_accuracy: 0.8603
#
# Best validation acc of epoch:
# 0.8672260642051697
# froz=
# 15
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 7s - loss: 0.8176 - accuracy: 0.7051 - val_loss: 4.5035 - val_accuracy: 0.6234
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3413 - accuracy: 0.8715 - val_loss: 0.8397 - val_accuracy: 0.7895
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2507 - accuracy: 0.9048 - val_loss: 0.4490 - val_accuracy: 0.8428
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1934 - accuracy: 0.9266 - val_loss: 0.4111 - val_accuracy: 0.8428
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1538 - accuracy: 0.9424 - val_loss: 0.4103 - val_accuracy: 0.8564
#
# Best validation acc of epoch:
# 0.8563672304153442
# froz=
# 25
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 8s - loss: 1.0277 - accuracy: 0.6037 - val_loss: 0.8718 - val_accuracy: 0.7184
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.7891 - accuracy: 0.8074 - val_loss: 0.8019 - val_accuracy: 0.6656
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.5930 - accuracy: 0.8493 - val_loss: 0.7108 - val_accuracy: 0.8522
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.3892 - accuracy: 0.8646 - val_loss: 0.6918 - val_accuracy: 0.8549
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.2897 - accuracy: 0.9123 - val_loss: 0.5646 - val_accuracy: 0.8574
#
# Best validation acc of epoch:
# 0.8573544025421143
# froz=
# 40
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 9s - loss: 1.0473 - accuracy: 0.5352 - val_loss: 1.4784 - val_accuracy: 0.5785
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.6046 - accuracy: 0.8177 - val_loss: 2.4456 - val_accuracy: 0.6535
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.3298 - accuracy: 0.8983 - val_loss: 0.8955 - val_accuracy: 0.8497
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.2394 - accuracy: 0.9215 - val_loss: 0.5100 - val_accuracy: 0.8830
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.1760 - accuracy: 0.9424 - val_loss: 0.5037 - val_accuracy: 0.8815
#
# Best validation acc of epoch:
# 0.8830207586288452
# froz=
# 3
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 6s - loss: 0.6464 - accuracy: 0.7315 - val_loss: 0.7117 - val_accuracy: 0.7626
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.4202 - accuracy: 0.8441 - val_loss: 0.5201 - val_accuracy: 0.8332
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.3419 - accuracy: 0.8731 - val_loss: 0.4551 - val_accuracy: 0.8514
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2845 - accuracy: 0.8948 - val_loss: 0.4834 - val_accuracy: 0.8472
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2306 - accuracy: 0.9126 - val_loss: 0.4520 - val_accuracy: 0.8581
#
# Best validation acc of epoch:
# 0.8580947518348694
# froz=
# 6
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 7s - loss: 0.6842 - accuracy: 0.7110 - val_loss: 0.8708 - val_accuracy: 0.7826
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3672 - accuracy: 0.8663 - val_loss: 0.5618 - val_accuracy: 0.8324
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2647 - accuracy: 0.9018 - val_loss: 0.5496 - val_accuracy: 0.8554
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2011 - accuracy: 0.9253 - val_loss: 1.0158 - val_accuracy: 0.7697
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1478 - accuracy: 0.9464 - val_loss: 0.6341 - val_accuracy: 0.8544
#
# Best validation acc of epoch:
# 0.8553800582885742
# froz=
# 3
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 6s - loss: 0.9956 - accuracy: 0.5147 - val_loss: 0.7343 - val_accuracy: 0.7258
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.8070 - accuracy: 0.6221 - val_loss: 0.6291 - val_accuracy: 0.7685
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.6987 - accuracy: 0.7047 - val_loss: 0.5236 - val_accuracy: 0.8292
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.6087 - accuracy: 0.7564 - val_loss: 0.4584 - val_accuracy: 0.8403
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.5261 - accuracy: 0.7903 - val_loss: 0.5114 - val_accuracy: 0.8504
#
# Best validation acc of epoch:
# 0.8504441976547241
# froz=
# 30
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 8s - loss: 1.0613 - accuracy: 0.4845 - val_loss: 14.6094 - val_accuracy: 0.4751
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.5300 - accuracy: 0.8309 - val_loss: 1.4346 - val_accuracy: 0.7352
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.2714 - accuracy: 0.8988 - val_loss: 1.0458 - val_accuracy: 0.7767
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1862 - accuracy: 0.9323 - val_loss: 0.5257 - val_accuracy: 0.8561
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.1238 - accuracy: 0.9559 - val_loss: 0.5817 - val_accuracy: 0.8292
#
# Best validation acc of epoch:
# 0.8561204075813293
# froz=
# 15
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 7s - loss: 0.7992 - accuracy: 0.6343 - val_loss: 1.0021 - val_accuracy: 0.7875
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.4642 - accuracy: 0.8292 - val_loss: 0.9534 - val_accuracy: 0.8467
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.3515 - accuracy: 0.8748 - val_loss: 0.5753 - val_accuracy: 0.8650
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2907 - accuracy: 0.8979 - val_loss: 0.5212 - val_accuracy: 0.8724
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2364 - accuracy: 0.9203 - val_loss: 0.7287 - val_accuracy: 0.8401
#
# Best validation acc of epoch:
# 0.8724086880683899
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 1.0897 - accuracy: 0.4484 - val_loss: 1.0569 - val_accuracy: 0.4640
#
# Epoch 2/5
# 17/17 - 10s - loss: 1.0617 - accuracy: 0.4578 - val_loss: 2.9166 - val_accuracy: 0.4640
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.6370 - accuracy: 0.7333 - val_loss: 0.9905 - val_accuracy: 0.8319
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.2892 - accuracy: 0.9012 - val_loss: 0.8610 - val_accuracy: 0.8754
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.2071 - accuracy: 0.9286 - val_loss: 0.6143 - val_accuracy: 0.8951
#
# Best validation acc of epoch:
# 0.8951135277748108
# froz=
# 6
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 7s - loss: 0.6374 - accuracy: 0.7568 - val_loss: 0.8018 - val_accuracy: 0.7717
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3271 - accuracy: 0.8777 - val_loss: 0.4354 - val_accuracy: 0.8571
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2252 - accuracy: 0.9139 - val_loss: 0.6075 - val_accuracy: 0.7786
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1545 - accuracy: 0.9427 - val_loss: 0.4189 - val_accuracy: 0.8551
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.0973 - accuracy: 0.9652 - val_loss: 0.4596 - val_accuracy: 0.8633
#
# Best validation acc of epoch:
# 0.8632773756980896
# froz=
# 6
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 7s - loss: 0.6568 - accuracy: 0.7495 - val_loss: 0.6310 - val_accuracy: 0.8144
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3436 - accuracy: 0.8704 - val_loss: 0.6591 - val_accuracy: 0.8090
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2433 - accuracy: 0.9071 - val_loss: 0.5003 - val_accuracy: 0.8472
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1760 - accuracy: 0.9336 - val_loss: 0.6829 - val_accuracy: 0.7994
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1131 - accuracy: 0.9584 - val_loss: 0.6062 - val_accuracy: 0.8591
#
# Best validation acc of epoch:
# 0.8590819239616394
# froz=
# 3
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 7s - loss: 0.8036 - accuracy: 0.6535 - val_loss: 0.6234 - val_accuracy: 0.8006
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.5356 - accuracy: 0.7994 - val_loss: 0.4954 - val_accuracy: 0.8391
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.4276 - accuracy: 0.8473 - val_loss: 0.4887 - val_accuracy: 0.8519
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.3554 - accuracy: 0.8738 - val_loss: 0.5405 - val_accuracy: 0.8448
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2999 - accuracy: 0.8935 - val_loss: 0.5408 - val_accuracy: 0.8576
#
# Best validation acc of epoch:
# 0.8576011657714844
# froz=
# 3
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 7s - loss: 0.5824 - accuracy: 0.7742 - val_loss: 1.0959 - val_accuracy: 0.7663
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3671 - accuracy: 0.8630 - val_loss: 0.9264 - val_accuracy: 0.8174
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2869 - accuracy: 0.8934 - val_loss: 0.7024 - val_accuracy: 0.8440
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2254 - accuracy: 0.9176 - val_loss: 0.6277 - val_accuracy: 0.8346
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1774 - accuracy: 0.9378 - val_loss: 0.5968 - val_accuracy: 0.8487
#
# Best validation acc of epoch:
# 0.848716676235199
# froz=
# 3
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 6s - loss: 0.6497 - accuracy: 0.7642 - val_loss: 0.5707 - val_accuracy: 0.8388
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3383 - accuracy: 0.8754 - val_loss: 0.5174 - val_accuracy: 0.8332
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2529 - accuracy: 0.9074 - val_loss: 0.4754 - val_accuracy: 0.8546
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1894 - accuracy: 0.9355 - val_loss: 0.4396 - val_accuracy: 0.8625
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1340 - accuracy: 0.9580 - val_loss: 0.4714 - val_accuracy: 0.8509
#
# Best validation acc of epoch:
# 0.8625370264053345
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 0.8319 - accuracy: 0.6473 - val_loss: 2.9097 - val_accuracy: 0.6737
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.3240 - accuracy: 0.8912 - val_loss: 2.8811 - val_accuracy: 0.7789
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.2232 - accuracy: 0.9249 - val_loss: 0.9470 - val_accuracy: 0.8529
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.1590 - accuracy: 0.9434 - val_loss: 0.8956 - val_accuracy: 0.8808
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1088 - accuracy: 0.9622 - val_loss: 0.9112 - val_accuracy: 0.8736
#
# Best validation acc of epoch:
# 0.8807995915412903
# froz=
# 40
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 9s - loss: 0.5929 - accuracy: 0.7701 - val_loss: 3.2812 - val_accuracy: 0.7071
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.2861 - accuracy: 0.9036 - val_loss: 1.1519 - val_accuracy: 0.8391
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.1874 - accuracy: 0.9336 - val_loss: 1.1736 - val_accuracy: 0.8458
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1433 - accuracy: 0.9508 - val_loss: 0.9585 - val_accuracy: 0.8838
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.0831 - accuracy: 0.9738 - val_loss: 1.7408 - val_accuracy: 0.8329
#
# Best validation acc of epoch:
# 0.8837611079216003
# froz=
# 40
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 9s - loss: 0.7930 - accuracy: 0.6407 - val_loss: 3.6026 - val_accuracy: 0.5795
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.3535 - accuracy: 0.8723 - val_loss: 2.4612 - val_accuracy: 0.6913
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.2298 - accuracy: 0.9224 - val_loss: 1.7867 - val_accuracy: 0.7544
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1618 - accuracy: 0.9454 - val_loss: 0.8909 - val_accuracy: 0.8292
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.1050 - accuracy: 0.9669 - val_loss: 1.2028 - val_accuracy: 0.8270
#
# Best validation acc of epoch:
# 0.8292201161384583
# froz=
# 20
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 8s - loss: 0.5151 - accuracy: 0.8012 - val_loss: 1.1163 - val_accuracy: 0.7885
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.2641 - accuracy: 0.9007 - val_loss: 0.6751 - val_accuracy: 0.8384
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.1858 - accuracy: 0.9282 - val_loss: 0.6498 - val_accuracy: 0.8746
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.1301 - accuracy: 0.9501 - val_loss: 0.5760 - val_accuracy: 0.8788
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.0875 - accuracy: 0.9665 - val_loss: 0.7705 - val_accuracy: 0.8801
#
# Best validation acc of epoch:
# 0.8800592422485352
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 0.5954 - accuracy: 0.7652 - val_loss: 3.3194 - val_accuracy: 0.7216
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.2622 - accuracy: 0.9097 - val_loss: 3.2586 - val_accuracy: 0.8144
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.1662 - accuracy: 0.9410 - val_loss: 2.2710 - val_accuracy: 0.8485
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.1234 - accuracy: 0.9579 - val_loss: 1.2108 - val_accuracy: 0.8628
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.0769 - accuracy: 0.9732 - val_loss: 1.0632 - val_accuracy: 0.8857
#
# Best validation acc of epoch:
# 0.8857354521751404
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 1.0972 - accuracy: 0.4501 - val_loss: 1.0871 - val_accuracy: 0.4642
#
# Epoch 2/5
# 17/17 - 10s - loss: 1.0818 - accuracy: 0.4660 - val_loss: 1.0489 - val_accuracy: 0.5022
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.9039 - accuracy: 0.6243 - val_loss: 0.9177 - val_accuracy: 0.6392
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.3412 - accuracy: 0.8857 - val_loss: 0.4720 - val_accuracy: 0.8722
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.2336 - accuracy: 0.9224 - val_loss: 0.3831 - val_accuracy: 0.8835
#
# Best validation acc of epoch:
# 0.8835142850875854
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 10s - loss: 1.1431 - accuracy: 0.4421 - val_loss: 1.0834 - val_accuracy: 0.4640
#
# Epoch 2/5
# 17/17 - 10s - loss: 1.0873 - accuracy: 0.4573 - val_loss: 1.0817 - val_accuracy: 0.4640
#
# Epoch 3/5
# 17/17 - 10s - loss: 1.0800 - accuracy: 0.4573 - val_loss: 1.0751 - val_accuracy: 0.4640
#
# Epoch 4/5
# 17/17 - 10s - loss: 1.0738 - accuracy: 0.4573 - val_loss: 1.0686 - val_accuracy: 0.4640
#
# Epoch 5/5
# 17/17 - 10s - loss: 1.0683 - accuracy: 0.4573 - val_loss: 1.0632 - val_accuracy: 0.4640
#
# Best validation acc of epoch:
# 0.4639683961868286
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 0.9156 - accuracy: 0.5500 - val_loss: 5.0358 - val_accuracy: 0.5814
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.3599 - accuracy: 0.8801 - val_loss: 2.9195 - val_accuracy: 0.8097
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.2392 - accuracy: 0.9178 - val_loss: 3.0491 - val_accuracy: 0.7730
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.1735 - accuracy: 0.9398 - val_loss: 1.4325 - val_accuracy: 0.8282
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1370 - accuracy: 0.9516 - val_loss: 0.7972 - val_accuracy: 0.8976
#
# Best validation acc of epoch:
# 0.8975814580917358
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 1.0870 - accuracy: 0.4764 - val_loss: 1.0859 - val_accuracy: 0.6014
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.8388 - accuracy: 0.7153 - val_loss: 1.0069 - val_accuracy: 0.7732
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.3146 - accuracy: 0.8918 - val_loss: 0.5349 - val_accuracy: 0.8894
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.2040 - accuracy: 0.9293 - val_loss: 0.6088 - val_accuracy: 0.8889
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1418 - accuracy: 0.9508 - val_loss: 0.7623 - val_accuracy: 0.8872
#
# Best validation acc of epoch:
# 0.8894373178482056
# froz=
# 10
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 7s - loss: 0.8470 - accuracy: 0.7077 - val_loss: 1.6590 - val_accuracy: 0.7962
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3952 - accuracy: 0.8615 - val_loss: 0.8504 - val_accuracy: 0.8522
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.3121 - accuracy: 0.8915 - val_loss: 0.6266 - val_accuracy: 0.8492
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2519 - accuracy: 0.9096 - val_loss: 0.5379 - val_accuracy: 0.8421
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2057 - accuracy: 0.9284 - val_loss: 0.4988 - val_accuracy: 0.8608
#
# Best validation acc of epoch:
# 0.8608095049858093
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 0.7580 - accuracy: 0.6694 - val_loss: 2.2122 - val_accuracy: 0.7169
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.3280 - accuracy: 0.8868 - val_loss: 0.7014 - val_accuracy: 0.8717
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.2288 - accuracy: 0.9191 - val_loss: 0.6322 - val_accuracy: 0.9079
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.1846 - accuracy: 0.9363 - val_loss: 0.6420 - val_accuracy: 0.9030
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1333 - accuracy: 0.9555 - val_loss: 0.6469 - val_accuracy: 0.8909
#
# Best validation acc of epoch:
# 0.9079467058181763
# froz=
# 20
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 8s - loss: 0.6398 - accuracy: 0.7491 - val_loss: 1.4105 - val_accuracy: 0.7796
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.3587 - accuracy: 0.8763 - val_loss: 0.6397 - val_accuracy: 0.8620
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.2808 - accuracy: 0.9027 - val_loss: 0.6113 - val_accuracy: 0.8776
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.2373 - accuracy: 0.9163 - val_loss: 0.6093 - val_accuracy: 0.8850
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.1838 - accuracy: 0.9320 - val_loss: 0.7182 - val_accuracy: 0.8872
#
# Best validation acc of epoch:
# 0.8872162103652954
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 1.0301 - accuracy: 0.4450 - val_loss: 1.7287 - val_accuracy: 0.6086
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.6125 - accuracy: 0.7353 - val_loss: 1.5670 - val_accuracy: 0.6555
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.3295 - accuracy: 0.8704 - val_loss: 1.1029 - val_accuracy: 0.7678
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.2446 - accuracy: 0.9029 - val_loss: 1.2006 - val_accuracy: 0.7976
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1896 - accuracy: 0.9344 - val_loss: 0.5316 - val_accuracy: 0.8983
#
# Best validation acc of epoch:
# 0.898321807384491
# froz=
# 10
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 7s - loss: 0.6030 - accuracy: 0.7655 - val_loss: 1.4654 - val_accuracy: 0.7638
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.3613 - accuracy: 0.8725 - val_loss: 0.8583 - val_accuracy: 0.8371
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.3015 - accuracy: 0.8889 - val_loss: 0.8237 - val_accuracy: 0.8482
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.2490 - accuracy: 0.9075 - val_loss: 0.8228 - val_accuracy: 0.8337
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.2084 - accuracy: 0.9218 - val_loss: 0.6043 - val_accuracy: 0.8655
#
# Best validation acc of epoch:
# 0.8654985427856445
# froz=
# 60
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 11s - loss: 0.4952 - accuracy: 0.8142 - val_loss: 3.4096 - val_accuracy: 0.7954
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.2146 - accuracy: 0.9200 - val_loss: 1.5765 - val_accuracy: 0.8490
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.1290 - accuracy: 0.9498 - val_loss: 1.3971 - val_accuracy: 0.8507
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.0700 - accuracy: 0.9747 - val_loss: 1.3131 - val_accuracy: 0.8660
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.0484 - accuracy: 0.9819 - val_loss: 0.8507 - val_accuracy: 0.8776
#
# Best validation acc of epoch:
# 0.8775913119316101
# froz=
# 25
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 8s - loss: 0.8330 - accuracy: 0.5885 - val_loss: 3.6054 - val_accuracy: 0.5484
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.4713 - accuracy: 0.8261 - val_loss: 4.1013 - val_accuracy: 0.6649
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.3197 - accuracy: 0.8872 - val_loss: 3.0316 - val_accuracy: 0.7386
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.2391 - accuracy: 0.9136 - val_loss: 1.7041 - val_accuracy: 0.7927
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.1927 - accuracy: 0.9301 - val_loss: 1.9710 - val_accuracy: 0.7885
#
# Best validation acc of epoch:
# 0.7926949858665466
# froz=
# 15
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 8s - loss: 0.5996 - accuracy: 0.7730 - val_loss: 1.1646 - val_accuracy: 0.8075
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.3449 - accuracy: 0.8801 - val_loss: 0.8394 - val_accuracy: 0.8319
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.2660 - accuracy: 0.9031 - val_loss: 0.5731 - val_accuracy: 0.8566
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.2202 - accuracy: 0.9208 - val_loss: 0.7866 - val_accuracy: 0.8309
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1885 - accuracy: 0.9318 - val_loss: 0.5778 - val_accuracy: 0.8704
#
# Best validation acc of epoch:
# 0.8704343438148499
# froz=
# 60
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 11s - loss: 0.9886 - accuracy: 0.5206 - val_loss: 1.1203 - val_accuracy: 0.7174
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.4384 - accuracy: 0.8522 - val_loss: 1.2286 - val_accuracy: 0.7769
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.2805 - accuracy: 0.9040 - val_loss: 0.7630 - val_accuracy: 0.8606
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.2083 - accuracy: 0.9256 - val_loss: 0.4426 - val_accuracy: 0.8949
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.1797 - accuracy: 0.9358 - val_loss: 0.4816 - val_accuracy: 0.9003
#
# Best validation acc of epoch:
# 0.900296151638031
# froz=
# 20
# dense_layers=
# 0
# Epoch 1/5
# 17/17 - 8s - loss: 0.4950 - accuracy: 0.8092 - val_loss: 1.0816 - val_accuracy: 0.7989
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.2459 - accuracy: 0.9074 - val_loss: 0.8179 - val_accuracy: 0.8272
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.1744 - accuracy: 0.9337 - val_loss: 0.6383 - val_accuracy: 0.8532
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.1175 - accuracy: 0.9561 - val_loss: 0.9749 - val_accuracy: 0.7855
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.0757 - accuracy: 0.9715 - val_loss: 0.8992 - val_accuracy: 0.8541
#
# Best validation acc of epoch:
# 0.8541461229324341
# froz=
# 25
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 8s - loss: 0.9110 - accuracy: 0.4895 - val_loss: 4.3494 - val_accuracy: 0.5424
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.6733 - accuracy: 0.6818 - val_loss: 4.2430 - val_accuracy: 0.6335
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.5665 - accuracy: 0.8613 - val_loss: 3.9795 - val_accuracy: 0.6811
#
# Epoch 4/5
# 17/17 - 7s - loss: 0.4918 - accuracy: 0.8901 - val_loss: 4.1511 - val_accuracy: 0.6957
#
# Epoch 5/5
# 17/17 - 7s - loss: 0.4299 - accuracy: 0.9169 - val_loss: 5.7452 - val_accuracy: 0.6979
#
# Best validation acc of epoch:
# 0.697926938533783
# froz=
# 30
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 8s - loss: 0.7605 - accuracy: 0.6025 - val_loss: 5.2367 - val_accuracy: 0.5696
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.4078 - accuracy: 0.8754 - val_loss: 2.6416 - val_accuracy: 0.7581
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.2100 - accuracy: 0.9241 - val_loss: 1.8402 - val_accuracy: 0.8213
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1345 - accuracy: 0.9530 - val_loss: 1.8589 - val_accuracy: 0.8166
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.0962 - accuracy: 0.9664 - val_loss: 1.4359 - val_accuracy: 0.8258
#
# Best validation acc of epoch:
# 0.825765073299408
# froz=
# 10
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 7s - loss: 0.5298 - accuracy: 0.7983 - val_loss: 1.4711 - val_accuracy: 0.7446
#
# Epoch 2/5
# 17/17 - 6s - loss: 0.2830 - accuracy: 0.8957 - val_loss: 0.6932 - val_accuracy: 0.8319
#
# Epoch 3/5
# 17/17 - 6s - loss: 0.2173 - accuracy: 0.9200 - val_loss: 0.4899 - val_accuracy: 0.8601
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1648 - accuracy: 0.9365 - val_loss: 0.6742 - val_accuracy: 0.8391
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1324 - accuracy: 0.9506 - val_loss: 0.4339 - val_accuracy: 0.8756
#
# Best validation acc of epoch:
# 0.8756169676780701
# froz=
# 60
# dense_layers=
# 3
# Epoch 1/5
# 17/17 - 11s - loss: 1.0864 - accuracy: 0.4490 - val_loss: 1.0485 - val_accuracy: 0.4640
#
# Epoch 2/5
# 17/17 - 10s - loss: 0.9611 - accuracy: 0.5690 - val_loss: 0.7350 - val_accuracy: 0.6957
#
# Epoch 3/5
# 17/17 - 10s - loss: 0.5860 - accuracy: 0.7798 - val_loss: 1.0448 - val_accuracy: 0.8211
#
# Epoch 4/5
# 17/17 - 10s - loss: 0.3025 - accuracy: 0.8974 - val_loss: 1.1480 - val_accuracy: 0.8722
#
# Epoch 5/5
# 17/17 - 10s - loss: 0.2110 - accuracy: 0.9279 - val_loss: 0.8412 - val_accuracy: 0.8963
#
# Best validation acc of epoch:
# 0.8963474631309509
# froz=
# 15
# dense_layers=
# 1
# Epoch 1/5
# 17/17 - 7s - loss: 0.5986 - accuracy: 0.7716 - val_loss: 0.7844 - val_accuracy: 0.8411
#
# Epoch 2/5
# 17/17 - 7s - loss: 0.2861 - accuracy: 0.8967 - val_loss: 0.6152 - val_accuracy: 0.8532
#
# Epoch 3/5
# 17/17 - 7s - loss: 0.2079 - accuracy: 0.9221 - val_loss: 0.8673 - val_accuracy: 0.8134
#
# Epoch 4/5
# 17/17 - 6s - loss: 0.1586 - accuracy: 0.9396 - val_loss: 0.8692 - val_accuracy: 0.8080
#
# Epoch 5/5
# 17/17 - 6s - loss: 0.1187 - accuracy: 0.9551 - val_loss: 0.8373 - val_accuracy: 0.8327
#
# Best validation acc of epoch:
# 0.8531589508056641
# froz=
# 30
# dense_layers=
# 2
# Epoch 1/5
# 17/17 - 8s - loss: 0.9057 - accuracy: 0.6379 - val_loss: 2.4895 - val_accuracy: 0.6510
#
# Epoch 2/5
# 17/17 - 8s - loss: 0.3269 - accuracy: 0.8827 - val_loss: 1.2166 - val_accuracy: 0.7715
#
# Epoch 3/5
# 17/17 - 8s - loss: 0.2120 - accuracy: 0.9241 - val_loss: 0.7095 - val_accuracy: 0.8633
#
# Epoch 4/5
# 17/17 - 8s - loss: 0.1481 - accuracy: 0.9456 - val_loss: 0.7342 - val_accuracy: 0.8623
#
# Epoch 5/5
# 17/17 - 8s - loss: 0.0978 - accuracy: 0.9647 - val_loss: 0.9020 - val_accuracy: 0.8667
#
# Best validation acc of epoch:
# 0.8667324781417847
# froz=
# 6
# dense_layers=
# 0
# Epoch 1/5
#  15%|█▌        | 45/300 [33:43<3:11:16, 45.01s/it, best loss: -0.9079467058181763]
